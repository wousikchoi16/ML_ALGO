# %% [markdown]
# ### Part 6. 나도 이제 AI Analyst 실습

# %% [markdown]
# # **1. 모듈 설치 및 호출**

# %%
# !pip install sklearn-genetic-opt # GA이용해서 하이퍼파라미터 찾는 것임. 
# !pip install -U scikit-learn #버전업데이트

# %%
import numpy as np
import pandas as pd
import tqdm
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from scipy.cluster import hierarchy
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn_genetic import GASearchCV
from sklearn_genetic.callbacks import ProgressBar
from sklearn_genetic.plots import plot_fitness_evolution
from sklearn_genetic.plots import plot_search_space
from sklearn_genetic.space import Integer, Continuous
from xgboost import XGBRegressor


pd.set_option('display.max_columns', None)

# %% [markdown]
# # **2. 데이터 로드 및 분석**

# %%
# collective_asset_data.csv 데이터 파일을 Colab에 업로드
# HTS에서 내려받은 데이터를 가공한 자체 제작 파일
# Chrome 사용시 'incognito'가 아닌 일반 모드 사용

# from google.colab import files, drive
# file_uploaded = files.upload()

# %%
# Colab에 데이터 파일을 올려놓은 경우
# drive.mount('./content')
# ! ls /content

# %%
raw_data = pd.read_csv('collective_asset_data.csv')
raw_data.head(5)
# Out:
#          date    KOSPI   CASH_close  SEC_close  SEC_dod_gain   SEC_std_1m  \
# 0  2019-03-04  2190.66  180000.0000    44850.0     -0.554324   733.501875
# 1  2019-03-05  2179.23  180013.1390    44250.0     -1.337793   779.627315
# 2  2019-03-06  2175.60  180026.2789    44000.0     -0.564972   889.592603
# 3  2019-03-07  2165.79  180039.4198    44450.0      1.022727  1002.780509
# 4  2019-03-08  2137.44  180052.5616    43800.0     -1.462317  1055.399806
#
#     SEC_std_2m   SEC_std_3m  SEC_relative_volatility_index      SEC_ATR  \
# 0  3245.879189  3146.418003                      61.574438  1071.428571
# 1  3148.683662  3160.304977                      52.014142  1025.000000
# 2  3054.692317  3167.420147                      42.697869  1017.857143
# 3  2953.008428  3172.387205                      45.675260  1032.142857
# 4  2785.128242  3180.712120                      43.122696   971.428571
#
#     SEC_BWI  SEC_sigma  SEC_standard_deviation  SEC_true_range  SBX_close  \
# 0  6.029839  -1.773283              812.234572          1300.0   376500.0
# 1  6.857710  -2.107706             1038.267788           950.0   382000.0
# 2  7.986223  -2.011906             1231.959821           600.0   378000.0
# 3  8.629859  -1.395206             1272.556482          1550.0   375000.0
# 4  9.225378  -1.742379             1327.676542          1000.0   373500.0
#
#    SBX_dod_gain   SBX_std_1m   SBX_std_2m   SBX_std_3m  \
# 0      0.132979  7229.929114  10497.71228  22003.79875
# 1      1.460823  6814.690015  10331.67968  21329.16038
# 2     -1.047120  6588.626564  10357.16996  20615.79537
# 3     -0.793651  4902.805319  10256.39482  19841.68394
# 4     -0.400000  4419.488093  10295.29790  19016.51003
#
#    SBX_relative_volatility_index      SBX_ATR   SBX_BWI  SBX_sigma  \
# 0                      50.313836  5321.428571  6.823589  -0.528271
# 1                      60.732073  5571.428571  6.559895   0.333909
# 2                      51.352693  5678.571429  5.168388  -0.152974
# 3                      43.420638  5678.571429  4.272319  -0.695782
# 4                      45.303062  5785.714286  4.293805  -0.955073
#
#    SBX_standard_deviation  SBX_true_range  ORN_close  ORN_dod_gain  \
# 0             5797.628826          3500.0   110500.0     -0.896861
# 1             5955.879448          8000.0   109500.0     -0.904977
# 2             5499.090834          6500.0   107500.0     -1.826484
# 3             4073.082371          7000.0   106000.0     -1.395349
# 4             3681.372027          5500.0   103000.0     -2.830189
#
#     ORN_std_1m   ORN_std_2m   ORN_std_3m  ORN_relative_volatility_index  \
# 0  1716.646440  4030.409394  3747.596202                      42.696306
# 1  1748.392118  4105.393211  3769.262095                      34.572470
# 2  1822.601163  4161.307281  3850.051567                      30.887108
# 3  2122.940178  4287.240175  3956.767172                      22.142687
# 4  2532.168043  4506.423468  4113.725298                      20.491745
#
#        ORN_ATR    ORN_BWI  ORN_sigma  ORN_standard_deviation  ORN_true_range  \
# 0  3071.428571   4.350540  -1.244000             1616.322988          2000.0
# 1  3071.428571   4.901692  -1.714582             1939.071943          2000.0
# 2  3035.714286   6.044119  -2.272791             2481.934729          2500.0
# 3  2785.714286   7.629736  -2.379384             2749.545417          3000.0
# 4  2750.000000  10.009868  -2.671000             3634.900274          3500.0
#
#    EMT_close  EMT_dod_gain   EMT_std_1m   EMT_std_2m   EMT_std_3m  \
# 0   180000.0      0.000000  5070.502934  7523.965280  6728.544689
# 1   182000.0      1.111111  4708.702050  7576.753797  6780.794368
# 2   177500.0     -2.472527  3671.767286  7582.836218  6740.486443
# 3   176000.0     -0.845070  2256.102835  7640.864339  6745.717385
# 4   176000.0      0.000000  2300.000000  7793.035986  6792.881647
#
#    EMT_relative_volatility_index      EMT_ATR   EMT_BWI  EMT_sigma  \
# 0                      49.590247  3964.285714  9.947476   0.026547
# 1                      59.669029  3857.142857  8.317233   0.728532
# 2                      49.551488  3892.857143  4.755575  -0.487566
# 3                      36.322949  3428.571429  4.563264  -1.043478
# 4                      45.452599  3214.285714  4.651398  -0.964652
#
#    EMT_standard_deviation  EMT_true_range  STD_avg_p1m  STD_yearly_f1m
# 0              943.398113          3500.0     0.004814        0.265382
# 1             1225.765067          4500.0     0.004656        0.234604
# 2             1378.404875          5000.0     0.004907        0.218217
# 3             1721.191448          2500.0     0.005018        0.203335
# 4             1955.121480          3000.0     0.005033        0.195859

# %%
# Data columns
# 
# date: date from 2019-03-04 to 2021-08-20
# 업종이 겹치지 않은 종목중에 큰 것. 
# Prefix list
# KOSPI: reference KOSPI index
# CASH: time deposits, matuarity 2 years, yield (APY) = 2.7%/y
# SEC: Samsung Electronics (삼성전자, 005930, KOSPI: 전기전자, WICS: 반도체와 반도체장비)
# SBX: Samsung Biologics (삼성바이오로직스, 207940, KOSPI: 의약품, WICS: 제약)
# ORN: Orion (오리온, 271560, KOSPI: 음식료품, WICS: 식품))
# EMT: Emart (이마트, 139480, KOSPI: 유통업, WICS: 백화점과 일반상점)
#
# Suffix list
# close (종가): closing price
# dod_gain (전일대비): day-on-day ratio
# std_1m (과거 한 달 표준편차): price's standard deviation during previous a month
# std_2m (과거 두 달 표준편차): price's standard deviation during previous two months
# std_3m (과거 세 달 표준편차): price's standard deviation during previous three months
# relative_volatility_index (상대 변동성 지수): 일정 기간 동안, 전일 대비 증가한 변동성과 감소한 변동성의 평균을 바탕으로 과변화된 값의 비율로 나타냄
# ATR (평균 True Range): 금일의 고저차, 금일과 전일의 고-저-종가 차이 중 큰 값을 평균낸 값
# BWI (Band Width Indicator): 주가 평균과 주가 사이의 편차
# sigma (): 특정기간 주가의 표준편차와 당일 주가의 차
# standard_deviation: 특정 기간의 변동성
# true_range: 금일의 고저차, 금일과 전일의 고-저-종가 차이 중 큰 값

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           614 non-null    object
#  1   KOSPI                          614 non-null    float64
#  2   CASH_close                     614 non-null    float64
#  3   SEC_close                      614 non-null    float64
#  4   SEC_dod_gain                   614 non-null    float64
#  5   SEC_std_1m                     614 non-null    float64
#  6   SEC_std_2m                     614 non-null    float64
#  7   SEC_std_3m                     614 non-null    float64
#  8   SEC_relative_volatility_index  614 non-null    float64
#  9   SEC_ATR                        614 non-null    float64
#  10  SEC_BWI                        614 non-null    float64
#  11  SEC_sigma                      614 non-null    float64
#  12  SEC_standard_deviation         614 non-null    float64
#  13  SEC_true_range                 614 non-null    float64
#  14  SBX_close                      614 non-null    float64
#  15  SBX_dod_gain                   614 non-null    float64
#  16  SBX_std_1m                     614 non-null    float64
#  17  SBX_std_2m                     614 non-null    float64
#  18  SBX_std_3m                     614 non-null    float64
#  19  SBX_relative_volatility_index  614 non-null    float64
#  20  SBX_ATR                        614 non-null    float64
#  21  SBX_BWI                        614 non-null    float64
#  22  SBX_sigma                      614 non-null    float64
#  23  SBX_standard_deviation         614 non-null    float64
#  24  SBX_true_range                 614 non-null    float64
#  25  ORN_close                      614 non-null    float64
#  26  ORN_dod_gain                   614 non-null    float64
#  27  ORN_std_1m                     614 non-null    float64
#  28  ORN_std_2m                     614 non-null    float64
#  29  ORN_std_3m                     614 non-null    float64
#  30  ORN_relative_volatility_index  614 non-null    float64
#  31  ORN_ATR                        614 non-null    float64
#  32  ORN_BWI                        614 non-null    float64
#  33  ORN_sigma                      614 non-null    float64
#  34  ORN_standard_deviation         614 non-null    float64
#  35  ORN_true_range                 614 non-null    float64
#  36  EMT_close                      614 non-null    float64
#  37  EMT_dod_gain                   614 non-null    float64
#  38  EMT_std_1m                     614 non-null    float64
#  39  EMT_std_2m                     614 non-null    float64
#  40  EMT_std_3m                     614 non-null    float64
#  41  EMT_relative_volatility_index  614 non-null    float64
#  42  EMT_ATR                        614 non-null    float64
#  43  EMT_BWI                        614 non-null    float64
#  44  EMT_sigma                      614 non-null    float64
#  45  EMT_standard_deviation         614 non-null    float64
#  46  EMT_true_range                 614 non-null    float64
#  47  STD_avg_p1m                    614 non-null    float64
#  48  STD_yearly_f1m                 614 non-null    float64
# dtypes: float64(48), object(1)
# memory usage: 243.6+ KB

# %%
df = raw_data.dropna()
df = df.reset_index(drop=True)
df
# Out:
#            date    KOSPI   CASH_close  SEC_close  SEC_dod_gain   SEC_std_1m  \
# 0    2019-03-04  2190.66  180000.0000    44850.0     -0.554324   733.501875
# 1    2019-03-05  2179.23  180013.1390    44250.0     -1.337793   779.627315
# 2    2019-03-06  2175.60  180026.2789    44000.0     -0.564972   889.592603
# 3    2019-03-07  2165.79  180039.4198    44450.0      1.022727  1002.780509
# 4    2019-03-08  2137.44  180052.5616    43800.0     -1.462317  1055.399806
# ..          ...      ...          ...        ...           ...          ...
# 609  2021-08-13  3171.29  192123.4900    74400.0     -3.376623  1440.928520
# 610  2021-08-17  3143.09  192179.5918    74200.0     -0.268817  1843.712288
# 611  2021-08-18  3158.93  192193.6198    73900.0     -0.404313  2166.304457
# 612  2021-08-19  3097.83  192207.6488    73100.0     -1.082544  2453.079697
# 613  2021-08-20  3060.51  192221.6789    72700.0     -0.547196  2762.154956
#
#       SEC_std_2m   SEC_std_3m  SEC_relative_volatility_index      SEC_ATR  \
# 0    3245.879189  3146.418003                      61.574438  1071.428571
# 1    3148.683662  3160.304977                      52.014142  1025.000000
# 2    3054.692317  3167.420147                      42.697869  1017.857143
# 3    2953.008428  3172.387205                      45.675260  1032.142857
# 4    2785.128242  3180.712120                      43.122696   971.428571
# ..           ...          ...                            ...          ...
# 609  1177.480548  1149.543919                      21.191471  1450.000000
# 610  1459.066712  1369.469773                      18.247743  1464.285714
# 611  1700.785415  1568.507251                      12.698001  1492.857143
# 612  1925.590834  1755.958872                      11.062669  1542.857143
# 613  2170.315115  1964.146517                       9.808069  1607.142857
#
#        SEC_BWI  SEC_sigma  SEC_standard_deviation  SEC_true_range  SBX_close  \
# 0     6.029839  -1.773283              812.234572          1300.0   376500.0
# 1     6.857710  -2.107706             1038.267788           950.0   382000.0
# 2     7.986223  -2.011906             1231.959821           600.0   378000.0
# 3     8.629859  -1.395206             1272.556482          1550.0   375000.0
# 4     9.225378  -1.742379             1327.676542          1000.0   373500.0
# ..         ...        ...                     ...             ...        ...
# 609   8.819124  -2.720056             2495.515979          2900.0   983000.0
# 610  10.455398  -2.296538             3026.565711          1100.0  1012000.0
# 611  12.068049  -2.046407             3343.291791          1500.0   993000.0
# 612  13.553120  -2.009301             3381.183225          1300.0   975000.0
# 613  14.989390  -1.844062             3316.624790          1400.0   986000.0
#
#      SBX_dod_gain    SBX_std_1m   SBX_std_2m   SBX_std_3m  \
# 0        0.132979   7229.929114  10497.71228  22003.79875
# 1        1.460823   6814.690015  10331.67968  21329.16038
# 2       -1.047120   6588.626564  10357.16996  20615.79537
# 3       -0.793651   4902.805319  10256.39482  19841.68394
# 4       -0.400000   4419.488093  10295.29790  19016.51003
# ..            ...           ...          ...          ...
# 609      1.131687  23662.417460  35159.43122  35722.24060
# 610      2.950153  27777.508890  37502.55197  38426.48128
# 611     -1.877470  34512.461520  41345.39876  42348.14945
# 612     -1.812689  37649.834000  43809.88890  44916.66864
# 613      1.128205  38567.343700  44851.99403  46508.41341
#
#      SBX_relative_volatility_index       SBX_ATR    SBX_BWI  SBX_sigma  \
# 0                        50.313836   5321.428571   6.823589  -0.528271
# 1                        60.732073   5571.428571   6.559895   0.333909
# 2                        51.352693   5678.571429   5.168388  -0.152974
# 3                        43.420638   5678.571429   4.272319  -0.695782
# 4                        45.303062   5785.714286   4.293805  -0.955073
# ..                             ...           ...        ...        ...
# 609                      60.741261  26785.714290  11.201333   2.343623
# 610                      64.567447  27928.571430  13.905366   2.587471
# 611                      57.839209  31000.000000  15.922079   1.760964
# 612                      48.906040  32071.428570  16.428554   1.156419
# 613                      56.156045  32428.571430  16.657050   1.300290
#
#      SBX_standard_deviation  SBX_true_range  ORN_close  ORN_dod_gain  \
# 0               5797.628826          3500.0   110500.0     -0.896861
# 1               5955.879448          8000.0   109500.0     -0.904977
# 2               5499.090834          6500.0   107500.0     -1.826484
# 3               4073.082371          7000.0   106000.0     -1.395349
# 4               3681.372027          5500.0   103000.0     -2.830189
# ..                      ...             ...        ...           ...
# 609            30092.523990         24000.0   116500.0     -0.851064
# 610            36984.996960         37000.0   116000.0     -0.429185
# 611            37593.217470         63000.0   117500.0      1.293103
# 612            34161.528070         32000.0   115500.0     -1.702128
# 613            30885.109680         29000.0   119500.0      3.463203
#
#       ORN_std_1m   ORN_std_2m   ORN_std_3m  ORN_relative_volatility_index  \
# 0    1716.646440  4030.409394  3747.596202                      42.696306
# 1    1748.392118  4105.393211  3769.262095                      34.572470
# 2    1822.601163  4161.307281  3850.051567                      30.887108
# 3    2122.940178  4287.240175  3956.767172                      22.142687
# 4    2532.168043  4506.423468  4113.725298                      20.491745
# ..           ...          ...          ...                            ...
# 609   982.344135  1214.134484  1200.476928                      28.413075
# 610   940.744386  1259.585496  1237.732059                      24.875359
# 611  1035.615759  1324.055566  1285.866779                      37.941417
# 612  1018.270593  1336.353906  1292.745350                      27.517512
# 613  1143.186337  1422.392518  1356.848317                      37.342202
#
#          ORN_ATR    ORN_BWI  ORN_sigma  ORN_standard_deviation  \
# 0    3071.428571   4.350540  -1.244000             1616.322988
# 1    3071.428571   4.901692  -1.714582             1939.071943
# 2    3035.714286   6.044119  -2.272791             2481.934729
# 3    2785.714286   7.629736  -2.379384             2749.545417
# 4    2750.000000  10.009868  -2.671000             3634.900274
# ..           ...        ...        ...                     ...
# 609  1571.428571   2.918988  -1.807080             1096.585610
# 610  1678.571429   3.114808  -1.979499             1264.911064
# 611  1750.000000   3.190861  -0.466477             1273.773920
# 612  1785.714286   3.489235  -2.033789             1264.911064
# 613  2071.428571   3.702767   1.405847             1171.537451
#
#      ORN_true_range  EMT_close  EMT_dod_gain   EMT_std_1m   EMT_std_2m  \
# 0            2000.0   180000.0      0.000000  5070.502934  7523.965280
# 1            2000.0   182000.0      1.111111  4708.702050  7576.753797
# 2            2500.0   177500.0     -2.472527  3671.767286  7582.836218
# 3            3000.0   176000.0     -0.845070  2256.102835  7640.864339
# 4            3500.0   176000.0      0.000000  2300.000000  7793.035986
# ..              ...        ...           ...          ...          ...
# 609          2500.0   175500.0      3.846154  5806.192815  6232.268124
# 610          2500.0   176500.0      0.569801  5887.009003  6499.485176
# 611          2500.0   177500.0      0.566572  5911.641058  6797.618297
# 612          2500.0   170500.0     -3.943662  5857.473858  7076.996442
# 613          6500.0   170000.0     -0.293255  5455.272679  7113.886179
#
#       EMT_std_3m  EMT_relative_volatility_index      EMT_ATR    EMT_BWI  \
# 0    6728.544689                      49.590247  3964.285714   9.947476
# 1    6780.794368                      59.669029  3857.142857   8.317233
# 2    6740.486443                      49.551488  3892.857143   4.755575
# 3    6745.717385                      36.322949  3428.571429   4.563264
# 4    6792.881647                      45.452599  3214.285714   4.651398
# ..           ...                            ...          ...        ...
# 609  5922.685606                      67.109389  4964.285714  13.439148
# 610  6070.910368                      67.237859  5000.000000  13.657015
# 611  6174.443866                      66.857324  4857.142857  13.232835
# 612  6387.207973                      58.066679  5214.285714  12.195279
# 613  6407.791800                      59.917375  5428.571429  10.660320
#
#      EMT_sigma  EMT_standard_deviation  EMT_true_range  STD_avg_p1m  \
# 0     0.026547              943.398113          3500.0     0.004814
# 1     0.728532             1225.765067          4500.0     0.004656
# 2    -0.487566             1378.404875          5000.0     0.004907
# 3    -1.043478             1721.191448          2500.0     0.005018
# 4    -0.964652             1955.121480          3000.0     0.005033
# ..         ...                     ...             ...          ...
# 609   1.244265             2439.774580          6500.0     0.006487
# 610   1.277141             2617.728023          8500.0     0.005731
# 611   1.314560             2891.366459          4000.0     0.005502
# 612   0.036662             3053.276928          8500.0     0.004964
# 613  -0.169619             3234.578798          6000.0     0.004534
#
#      STD_yearly_f1m
# 0          0.265382
# 1          0.234604
# 2          0.218217
# 3          0.203335
# 4          0.195859
# ..              ...
# 609        0.164748
# 610        0.166195
# 611        0.170362
# 612        0.151466
# 613        0.139222
#
# [614 rows x 49 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           614 non-null    datetime64[ns]
#  1   KOSPI                          614 non-null    float64
#  2   CASH_close                     614 non-null    float64
#  3   SEC_close                      614 non-null    float64
#  4   SEC_dod_gain                   614 non-null    float64
#  5   SEC_std_1m                     614 non-null    float64
#  6   SEC_std_2m                     614 non-null    float64
#  7   SEC_std_3m                     614 non-null    float64
#  8   SEC_relative_volatility_index  614 non-null    float64
#  9   SEC_ATR                        614 non-null    float64
#  10  SEC_BWI                        614 non-null    float64
#  11  SEC_sigma                      614 non-null    float64
#  12  SEC_standard_deviation         614 non-null    float64
#  13  SEC_true_range                 614 non-null    float64
#  14  SBX_close                      614 non-null    float64
#  15  SBX_dod_gain                   614 non-null    float64
#  16  SBX_std_1m                     614 non-null    float64
#  17  SBX_std_2m                     614 non-null    float64
#  18  SBX_std_3m                     614 non-null    float64
#  19  SBX_relative_volatility_index  614 non-null    float64
#  20  SBX_ATR                        614 non-null    float64
#  21  SBX_BWI                        614 non-null    float64
#  22  SBX_sigma                      614 non-null    float64
#  23  SBX_standard_deviation         614 non-null    float64
#  24  SBX_true_range                 614 non-null    float64
#  25  ORN_close                      614 non-null    float64
#  26  ORN_dod_gain                   614 non-null    float64
#  27  ORN_std_1m                     614 non-null    float64
#  28  ORN_std_2m                     614 non-null    float64
#  29  ORN_std_3m                     614 non-null    float64
#  30  ORN_relative_volatility_index  614 non-null    float64
#  31  ORN_ATR                        614 non-null    float64
#  32  ORN_BWI                        614 non-null    float64
#  33  ORN_sigma                      614 non-null    float64
#  34  ORN_standard_deviation         614 non-null    float64
#  35  ORN_true_range                 614 non-null    float64
#  36  EMT_close                      614 non-null    float64
#  37  EMT_dod_gain                   614 non-null    float64
#  38  EMT_std_1m                     614 non-null    float64
#  39  EMT_std_2m                     614 non-null    float64
#  40  EMT_std_3m                     614 non-null    float64
#  41  EMT_relative_volatility_index  614 non-null    float64
#  42  EMT_ATR                        614 non-null    float64
#  43  EMT_BWI                        614 non-null    float64
#  44  EMT_sigma                      614 non-null    float64
#  45  EMT_standard_deviation         614 non-null    float64
#  46  EMT_true_range                 614 non-null    float64
#  47  STD_avg_p1m                    614 non-null    float64
#  48  STD_yearly_f1m                 614 non-null    float64
# dtypes: datetime64[ns](1), float64(48)
# memory usage: 235.2 KB

# %%
# 굳이 float64까지 쓸피요없는 것은 int로 하자
# 주가는 소수점일 수 없다. TrueRange도 주가 차이이기 때문에 소수점이 아님. 
int_columns = ['SEC_close', 'SEC_true_range',
               'SBX_close', 'SBX_true_range',
               'ORN_close', 'ORN_true_range',
               'EMT_close', 'EMT_true_range'] 
df[int_columns] = df[int_columns].astype('int32') # 형변환
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           614 non-null    datetime64[ns]
#  1   KOSPI                          614 non-null    float64
#  2   CASH_close                     614 non-null    float64
#  3   SEC_close                      614 non-null    int32
#  4   SEC_dod_gain                   614 non-null    float64
#  5   SEC_std_1m                     614 non-null    float64
#  6   SEC_std_2m                     614 non-null    float64
#  7   SEC_std_3m                     614 non-null    float64
#  8   SEC_relative_volatility_index  614 non-null    float64
#  9   SEC_ATR                        614 non-null    float64
#  10  SEC_BWI                        614 non-null    float64
#  11  SEC_sigma                      614 non-null    float64
#  12  SEC_standard_deviation         614 non-null    float64
#  13  SEC_true_range                 614 non-null    int32
#  14  SBX_close                      614 non-null    int32
#  15  SBX_dod_gain                   614 non-null    float64
#  16  SBX_std_1m                     614 non-null    float64
#  17  SBX_std_2m                     614 non-null    float64
#  18  SBX_std_3m                     614 non-null    float64
#  19  SBX_relative_volatility_index  614 non-null    float64
#  20  SBX_ATR                        614 non-null    float64
#  21  SBX_BWI                        614 non-null    float64
#  22  SBX_sigma                      614 non-null    float64
#  23  SBX_standard_deviation         614 non-null    float64
#  24  SBX_true_range                 614 non-null    int32
#  25  ORN_close                      614 non-null    int32
#  26  ORN_dod_gain                   614 non-null    float64
#  27  ORN_std_1m                     614 non-null    float64
#  28  ORN_std_2m                     614 non-null    float64
#  29  ORN_std_3m                     614 non-null    float64
#  30  ORN_relative_volatility_index  614 non-null    float64
#  31  ORN_ATR                        614 non-null    float64
#  32  ORN_BWI                        614 non-null    float64
#  33  ORN_sigma                      614 non-null    float64
#  34  ORN_standard_deviation         614 non-null    float64
#  35  ORN_true_range                 614 non-null    int32
#  36  EMT_close                      614 non-null    int32
#  37  EMT_dod_gain                   614 non-null    float64
#  38  EMT_std_1m                     614 non-null    float64
#  39  EMT_std_2m                     614 non-null    float64
#  40  EMT_std_3m                     614 non-null    float64
#  41  EMT_relative_volatility_index  614 non-null    float64
#  42  EMT_ATR                        614 non-null    float64
#  43  EMT_BWI                        614 non-null    float64
#  44  EMT_sigma                      614 non-null    float64
#  45  EMT_standard_deviation         614 non-null    float64
#  46  EMT_true_range                 614 non-null    int32
#  47  STD_avg_p1m                    614 non-null    float64
#  48  STD_yearly_f1m                 614 non-null    float64
# dtypes: datetime64[ns](1), float64(40), int32(8)
# memory usage: 216.0 KB

# %% [markdown]
# # **3. 다중공선성 확인**

# %%
# output쓸 것 빼준다. 
# 분석에 사용안할 값빼준다. x만 넣음
features_cor = list(df)
features_cor.remove('date')
features_cor.remove('STD_yearly_f1m')
features_cor.remove('KOSPI') 

# 공선성 위배되는 피쳐없음
x_input = df[features_cor]
cor_table = x_input.corr()
print(cor_table[cor_table > 0.95])
print(cor_table[cor_table < -0.95])

# 이전실습과 같음. 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
ax1.set_title('Hierarchical dendrogram')
corr = spearmanr(x_input).correlation
corr_linkage = hierarchy.ward(corr)
dendro = hierarchy.dendrogram(corr_linkage, labels=features_cor, ax=ax1, leaf_rotation=90)

dendro_idx = np.arange(0, len(dendro['ivl']))

ax2.imshow(corr[dendro['leaves'], :][:, dendro['leaves']])
ax2.set_title('Feature correlation')
ax2.set_xticks(dendro_idx)
ax2.set_yticks(dendro_idx)
ax2.set_xticklabels(dendro['ivl'], rotation='vertical')
ax2.set_yticklabels(dendro['ivl'])

fig.tight_layout()
# Out:
#                                CASH_close  SEC_close  SEC_dod_gain  \
# CASH_close                            1.0        NaN           NaN
# SEC_close                             NaN        1.0           NaN
# SEC_dod_gain                          NaN        NaN           1.0
# SEC_std_1m                            NaN        NaN           NaN
# SEC_std_2m                            NaN        NaN           NaN
# SEC_std_3m                            NaN        NaN           NaN
# SEC_relative_volatility_index         NaN        NaN           NaN
# SEC_ATR                               NaN        NaN           NaN
# SEC_BWI                               NaN        NaN           NaN
# SEC_sigma                             NaN        NaN           NaN
# SEC_standard_deviation                NaN        NaN           NaN
# SEC_true_range                        NaN        NaN           NaN
# SBX_close                             NaN        NaN           NaN
# SBX_dod_gain                          NaN        NaN           NaN
# SBX_std_1m                            NaN        NaN           NaN
# SBX_std_2m                            NaN        NaN           NaN
# SBX_std_3m                            NaN        NaN           NaN
# SBX_relative_volatility_index         NaN        NaN           NaN
# SBX_ATR                               NaN        NaN           NaN
# SBX_BWI                               NaN        NaN           NaN
# SBX_sigma                             NaN        NaN           NaN
# SBX_standard_deviation                NaN        NaN           NaN
# SBX_true_range                        NaN        NaN           NaN
# ORN_close                             NaN        NaN           NaN
# ORN_dod_gain                          NaN        NaN           NaN
# ORN_std_1m                            NaN        NaN           NaN
# ORN_std_2m                            NaN        NaN           NaN
# ORN_std_3m                            NaN        NaN           NaN
# ORN_relative_volatility_index         NaN        NaN           NaN
# ORN_ATR                               NaN        NaN           NaN
# ORN_BWI                               NaN        NaN           NaN
# ORN_sigma                             NaN        NaN           NaN
# ORN_standard_deviation                NaN        NaN           NaN
# ORN_true_range                        NaN        NaN           NaN
# EMT_close                             NaN        NaN           NaN
# EMT_dod_gain                          NaN        NaN           NaN
# EMT_std_1m                            NaN        NaN           NaN
# EMT_std_2m                            NaN        NaN           NaN
# EMT_std_3m                            NaN        NaN           NaN
# EMT_relative_volatility_index         NaN        NaN           NaN
# EMT_ATR                               NaN        NaN           NaN
# EMT_BWI                               NaN        NaN           NaN
# EMT_sigma                             NaN        NaN           NaN
# EMT_standard_deviation                NaN        NaN           NaN
# EMT_true_range                        NaN        NaN           NaN
# STD_avg_p1m                           NaN        NaN           NaN
#
#                                SEC_std_1m  SEC_std_2m  SEC_std_3m  \
# CASH_close                            NaN         NaN         NaN
# SEC_close                             NaN         NaN         NaN
# SEC_dod_gain                          NaN         NaN         NaN
# SEC_std_1m                            1.0         NaN         NaN
# SEC_std_2m                            NaN         1.0         NaN
# SEC_std_3m                            NaN         NaN         1.0
# SEC_relative_volatility_index         NaN         NaN         NaN
# SEC_ATR                               NaN         NaN         NaN
# SEC_BWI                               NaN         NaN         NaN
# SEC_sigma                             NaN         NaN         NaN
# SEC_standard_deviation                NaN         NaN         NaN
# SEC_true_range                        NaN         NaN         NaN
# SBX_close                             NaN         NaN         NaN
# SBX_dod_gain                          NaN         NaN         NaN
# SBX_std_1m                            NaN         NaN         NaN
# SBX_std_2m                            NaN         NaN         NaN
# SBX_std_3m                            NaN         NaN         NaN
# SBX_relative_volatility_index         NaN         NaN         NaN
# SBX_ATR                               NaN         NaN         NaN
# SBX_BWI                               NaN         NaN         NaN
# SBX_sigma                             NaN         NaN         NaN
# SBX_standard_deviation                NaN         NaN         NaN
# SBX_true_range                        NaN         NaN         NaN
# ORN_close                             NaN         NaN         NaN
# ORN_dod_gain                          NaN         NaN         NaN
# ORN_std_1m                            NaN         NaN         NaN
# ORN_std_2m                            NaN         NaN         NaN
# ORN_std_3m                            NaN         NaN         NaN
# ORN_relative_volatility_index         NaN         NaN         NaN
# ORN_ATR                               NaN         NaN         NaN
# ORN_BWI                               NaN         NaN         NaN
# ORN_sigma                             NaN         NaN         NaN
# ORN_standard_deviation                NaN         NaN         NaN
# ORN_true_range                        NaN         NaN         NaN
# EMT_close                             NaN         NaN         NaN
# EMT_dod_gain                          NaN         NaN         NaN
# EMT_std_1m                            NaN         NaN         NaN
# EMT_std_2m                            NaN         NaN         NaN
# EMT_std_3m                            NaN         NaN         NaN
# EMT_relative_volatility_index         NaN         NaN         NaN
# EMT_ATR                               NaN         NaN         NaN
# EMT_BWI                               NaN         NaN         NaN
# EMT_sigma                             NaN         NaN         NaN
# EMT_standard_deviation                NaN         NaN         NaN
# EMT_true_range                        NaN         NaN         NaN
# STD_avg_p1m                           NaN         NaN         NaN
#
#                                SEC_relative_volatility_index  SEC_ATR  \
# CASH_close                                               NaN      NaN
# SEC_close                                                NaN      NaN
# SEC_dod_gain                                             NaN      NaN
# SEC_std_1m                                               NaN      NaN
# SEC_std_2m                                               NaN      NaN
# SEC_std_3m                                               NaN      NaN
# SEC_relative_volatility_index                            1.0      NaN
# SEC_ATR                                                  NaN      1.0
# SEC_BWI                                                  NaN      NaN
# SEC_sigma                                                NaN      NaN
# SEC_standard_deviation                                   NaN      NaN
# SEC_true_range                                           NaN      NaN
# SBX_close                                                NaN      NaN
# SBX_dod_gain                                             NaN      NaN
# SBX_std_1m                                               NaN      NaN
# SBX_std_2m                                               NaN      NaN
# SBX_std_3m                                               NaN      NaN
# SBX_relative_volatility_index                            NaN      NaN
# SBX_ATR                                                  NaN      NaN
# SBX_BWI                                                  NaN      NaN
# SBX_sigma                                                NaN      NaN
# SBX_standard_deviation                                   NaN      NaN
# SBX_true_range                                           NaN      NaN
# ORN_close                                                NaN      NaN
# ORN_dod_gain                                             NaN      NaN
# ORN_std_1m                                               NaN      NaN
# ORN_std_2m                                               NaN      NaN
# ORN_std_3m                                               NaN      NaN
# ORN_relative_volatility_index                            NaN      NaN
# ORN_ATR                                                  NaN      NaN
# ORN_BWI                                                  NaN      NaN
# ORN_sigma                                                NaN      NaN
# ORN_standard_deviation                                   NaN      NaN
# ORN_true_range                                           NaN      NaN
# EMT_close                                                NaN      NaN
# EMT_dod_gain                                             NaN      NaN
# EMT_std_1m                                               NaN      NaN
# EMT_std_2m                                               NaN      NaN
# EMT_std_3m                                               NaN      NaN
# EMT_relative_volatility_index                            NaN      NaN
# EMT_ATR                                                  NaN      NaN
# EMT_BWI                                                  NaN      NaN
# EMT_sigma                                                NaN      NaN
# EMT_standard_deviation                                   NaN      NaN
# EMT_true_range                                           NaN      NaN
# STD_avg_p1m                                              NaN      NaN
#
#                                SEC_BWI  SEC_sigma  SEC_standard_deviation  \
# CASH_close                         NaN        NaN                     NaN
# SEC_close                          NaN        NaN                     NaN
# SEC_dod_gain                       NaN        NaN                     NaN
# SEC_std_1m                         NaN        NaN                     NaN
# SEC_std_2m                         NaN        NaN                     NaN
# SEC_std_3m                         NaN        NaN                     NaN
# SEC_relative_volatility_index      NaN        NaN                     NaN
# SEC_ATR                            NaN        NaN                     NaN
# SEC_BWI                            1.0        NaN                     NaN
# SEC_sigma                          NaN        1.0                     NaN
# SEC_standard_deviation             NaN        NaN                     1.0
# SEC_true_range                     NaN        NaN                     NaN
# SBX_close                          NaN        NaN                     NaN
# SBX_dod_gain                       NaN        NaN                     NaN
# SBX_std_1m                         NaN        NaN                     NaN
# SBX_std_2m                         NaN        NaN                     NaN
# SBX_std_3m                         NaN        NaN                     NaN
# SBX_relative_volatility_index      NaN        NaN                     NaN
# SBX_ATR                            NaN        NaN                     NaN
# SBX_BWI                            NaN        NaN                     NaN
# SBX_sigma                          NaN        NaN                     NaN
# SBX_standard_deviation             NaN        NaN                     NaN
# SBX_true_range                     NaN        NaN                     NaN
# ORN_close                          NaN        NaN                     NaN
# ORN_dod_gain                       NaN        NaN                     NaN
# ORN_std_1m                         NaN        NaN                     NaN
# ORN_std_2m                         NaN        NaN                     NaN
# ORN_std_3m                         NaN        NaN                     NaN
# ORN_relative_volatility_index      NaN        NaN                     NaN
# ORN_ATR                            NaN        NaN                     NaN
# ORN_BWI                            NaN        NaN                     NaN
# ORN_sigma                          NaN        NaN                     NaN
# ORN_standard_deviation             NaN        NaN                     NaN
# ORN_true_range                     NaN        NaN                     NaN
# EMT_close                          NaN        NaN                     NaN
# EMT_dod_gain                       NaN        NaN                     NaN
# EMT_std_1m                         NaN        NaN                     NaN
# EMT_std_2m                         NaN        NaN                     NaN
# EMT_std_3m                         NaN        NaN                     NaN
# EMT_relative_volatility_index      NaN        NaN                     NaN
# EMT_ATR                            NaN        NaN                     NaN
# EMT_BWI                            NaN        NaN                     NaN
# EMT_sigma                          NaN        NaN                     NaN
# EMT_standard_deviation             NaN        NaN                     NaN
# EMT_true_range                     NaN        NaN                     NaN
# STD_avg_p1m                        NaN        NaN                     NaN
#
#                                SEC_true_range  SBX_close  SBX_dod_gain  \
# CASH_close                                NaN        NaN           NaN
# SEC_close                                 NaN        NaN           NaN
# SEC_dod_gain                              NaN        NaN           NaN
# SEC_std_1m                                NaN        NaN           NaN
# SEC_std_2m                                NaN        NaN           NaN
# SEC_std_3m                                NaN        NaN           NaN
# SEC_relative_volatility_index             NaN        NaN           NaN
# SEC_ATR                                   NaN        NaN           NaN
# SEC_BWI                                   NaN        NaN           NaN
# SEC_sigma                                 NaN        NaN           NaN
# SEC_standard_deviation                    NaN        NaN           NaN
# SEC_true_range                            1.0        NaN           NaN
# SBX_close                                 NaN        1.0           NaN
# SBX_dod_gain                              NaN        NaN           1.0
# SBX_std_1m                                NaN        NaN           NaN
# SBX_std_2m                                NaN        NaN           NaN
# SBX_std_3m                                NaN        NaN           NaN
# SBX_relative_volatility_index             NaN        NaN           NaN
# SBX_ATR                                   NaN        NaN           NaN
# SBX_BWI                                   NaN        NaN           NaN
# SBX_sigma                                 NaN        NaN           NaN
# SBX_standard_deviation                    NaN        NaN           NaN
# SBX_true_range                            NaN        NaN           NaN
# ORN_close                                 NaN        NaN           NaN
# ORN_dod_gain                              NaN        NaN           NaN
# ORN_std_1m                                NaN        NaN           NaN
# ORN_std_2m                                NaN        NaN           NaN
# ORN_std_3m                                NaN        NaN           NaN
# ORN_relative_volatility_index             NaN        NaN           NaN
# ORN_ATR                                   NaN        NaN           NaN
# ORN_BWI                                   NaN        NaN           NaN
# ORN_sigma                                 NaN        NaN           NaN
# ORN_standard_deviation                    NaN        NaN           NaN
# ORN_true_range                            NaN        NaN           NaN
# EMT_close                                 NaN        NaN           NaN
# EMT_dod_gain                              NaN        NaN           NaN
# EMT_std_1m                                NaN        NaN           NaN
# EMT_std_2m                                NaN        NaN           NaN
# EMT_std_3m                                NaN        NaN           NaN
# EMT_relative_volatility_index             NaN        NaN           NaN
# EMT_ATR                                   NaN        NaN           NaN
# EMT_BWI                                   NaN        NaN           NaN
# EMT_sigma                                 NaN        NaN           NaN
# EMT_standard_deviation                    NaN        NaN           NaN
# EMT_true_range                            NaN        NaN           NaN
# STD_avg_p1m                               NaN        NaN           NaN
#
#                                SBX_std_1m  SBX_std_2m  SBX_std_3m  \
# CASH_close                            NaN         NaN         NaN
# SEC_close                             NaN         NaN         NaN
# SEC_dod_gain                          NaN         NaN         NaN
# SEC_std_1m                            NaN         NaN         NaN
# SEC_std_2m                            NaN         NaN         NaN
# SEC_std_3m                            NaN         NaN         NaN
# SEC_relative_volatility_index         NaN         NaN         NaN
# SEC_ATR                               NaN         NaN         NaN
# SEC_BWI                               NaN         NaN         NaN
# SEC_sigma                             NaN         NaN         NaN
# SEC_standard_deviation                NaN         NaN         NaN
# SEC_true_range                        NaN         NaN         NaN
# SBX_close                             NaN         NaN         NaN
# SBX_dod_gain                          NaN         NaN         NaN
# SBX_std_1m                            1.0         NaN         NaN
# SBX_std_2m                            NaN         1.0         NaN
# SBX_std_3m                            NaN         NaN         1.0
# SBX_relative_volatility_index         NaN         NaN         NaN
# SBX_ATR                               NaN         NaN         NaN
# SBX_BWI                               NaN         NaN         NaN
# SBX_sigma                             NaN         NaN         NaN
# SBX_standard_deviation                NaN         NaN         NaN
# SBX_true_range                        NaN         NaN         NaN
# ORN_close                             NaN         NaN         NaN
# ORN_dod_gain                          NaN         NaN         NaN
# ORN_std_1m                            NaN         NaN         NaN
# ORN_std_2m                            NaN         NaN         NaN
# ORN_std_3m                            NaN         NaN         NaN
# ORN_relative_volatility_index         NaN         NaN         NaN
# ORN_ATR                               NaN         NaN         NaN
# ORN_BWI                               NaN         NaN         NaN
# ORN_sigma                             NaN         NaN         NaN
# ORN_standard_deviation                NaN         NaN         NaN
# ORN_true_range                        NaN         NaN         NaN
# EMT_close                             NaN         NaN         NaN
# EMT_dod_gain                          NaN         NaN         NaN
# EMT_std_1m                            NaN         NaN         NaN
# EMT_std_2m                            NaN         NaN         NaN
# EMT_std_3m                            NaN         NaN         NaN
# EMT_relative_volatility_index         NaN         NaN         NaN
# EMT_ATR                               NaN         NaN         NaN
# EMT_BWI                               NaN         NaN         NaN
# EMT_sigma                             NaN         NaN         NaN
# EMT_standard_deviation                NaN         NaN         NaN
# EMT_true_range                        NaN         NaN         NaN
# STD_avg_p1m                           NaN         NaN         NaN
#
#                                SBX_relative_volatility_index  SBX_ATR  \
# CASH_close                                               NaN      NaN
# SEC_close                                                NaN      NaN
# SEC_dod_gain                                             NaN      NaN
# SEC_std_1m                                               NaN      NaN
# SEC_std_2m                                               NaN      NaN
# SEC_std_3m                                               NaN      NaN
# SEC_relative_volatility_index                            NaN      NaN
# SEC_ATR                                                  NaN      NaN
# SEC_BWI                                                  NaN      NaN
# SEC_sigma                                                NaN      NaN
# SEC_standard_deviation                                   NaN      NaN
# SEC_true_range                                           NaN      NaN
# SBX_close                                                NaN      NaN
# SBX_dod_gain                                             NaN      NaN
# SBX_std_1m                                               NaN      NaN
# SBX_std_2m                                               NaN      NaN
# SBX_std_3m                                               NaN      NaN
# SBX_relative_volatility_index                            1.0      NaN
# SBX_ATR                                                  NaN      1.0
# SBX_BWI                                                  NaN      NaN
# SBX_sigma                                                NaN      NaN
# SBX_standard_deviation                                   NaN      NaN
# SBX_true_range                                           NaN      NaN
# ORN_close                                                NaN      NaN
# ORN_dod_gain                                             NaN      NaN
# ORN_std_1m                                               NaN      NaN
# ORN_std_2m                                               NaN      NaN
# ORN_std_3m                                               NaN      NaN
# ORN_relative_volatility_index                            NaN      NaN
# ORN_ATR                                                  NaN      NaN
# ORN_BWI                                                  NaN      NaN
# ORN_sigma                                                NaN      NaN
# ORN_standard_deviation                                   NaN      NaN
# ORN_true_range                                           NaN      NaN
# EMT_close                                                NaN      NaN
# EMT_dod_gain                                             NaN      NaN
# EMT_std_1m                                               NaN      NaN
# EMT_std_2m                                               NaN      NaN
# EMT_std_3m                                               NaN      NaN
# EMT_relative_volatility_index                            NaN      NaN
# EMT_ATR                                                  NaN      NaN
# EMT_BWI                                                  NaN      NaN
# EMT_sigma                                                NaN      NaN
# EMT_standard_deviation                                   NaN      NaN
# EMT_true_range                                           NaN      NaN
# STD_avg_p1m                                              NaN      NaN
#
#                                SBX_BWI  SBX_sigma  SBX_standard_deviation  \
# CASH_close                         NaN        NaN                     NaN
# SEC_close                          NaN        NaN                     NaN
# SEC_dod_gain                       NaN        NaN                     NaN
# SEC_std_1m                         NaN        NaN                     NaN
# SEC_std_2m                         NaN        NaN                     NaN
# SEC_std_3m                         NaN        NaN                     NaN
# SEC_relative_volatility_index      NaN        NaN                     NaN
# SEC_ATR                            NaN        NaN                     NaN
# SEC_BWI                            NaN        NaN                     NaN
# SEC_sigma                          NaN        NaN                     NaN
# SEC_standard_deviation             NaN        NaN                     NaN
# SEC_true_range                     NaN        NaN                     NaN
# SBX_close                          NaN        NaN                     NaN
# SBX_dod_gain                       NaN        NaN                     NaN
# SBX_std_1m                         NaN        NaN                     NaN
# SBX_std_2m                         NaN        NaN                     NaN
# SBX_std_3m                         NaN        NaN                     NaN
# SBX_relative_volatility_index      NaN        NaN                     NaN
# SBX_ATR                            NaN        NaN                     NaN
# SBX_BWI                            1.0        NaN                     NaN
# SBX_sigma                          NaN        1.0                     NaN
# SBX_standard_deviation             NaN        NaN                     1.0
# SBX_true_range                     NaN        NaN                     NaN
# ORN_close                          NaN        NaN                     NaN
# ORN_dod_gain                       NaN        NaN                     NaN
# ORN_std_1m                         NaN        NaN                     NaN
# ORN_std_2m                         NaN        NaN                     NaN
# ORN_std_3m                         NaN        NaN                     NaN
# ORN_relative_volatility_index      NaN        NaN                     NaN
# ORN_ATR                            NaN        NaN                     NaN
# ORN_BWI                            NaN        NaN                     NaN
# ORN_sigma                          NaN        NaN                     NaN
# ORN_standard_deviation             NaN        NaN                     NaN
# ORN_true_range                     NaN        NaN                     NaN
# EMT_close                          NaN        NaN                     NaN
# EMT_dod_gain                       NaN        NaN                     NaN
# EMT_std_1m                         NaN        NaN                     NaN
# EMT_std_2m                         NaN        NaN                     NaN
# EMT_std_3m                         NaN        NaN                     NaN
# EMT_relative_volatility_index      NaN        NaN                     NaN
# EMT_ATR                            NaN        NaN                     NaN
# EMT_BWI                            NaN        NaN                     NaN
# EMT_sigma                          NaN        NaN                     NaN
# EMT_standard_deviation             NaN        NaN                     NaN
# EMT_true_range                     NaN        NaN                     NaN
# STD_avg_p1m                        NaN        NaN                     NaN
#
#                                SBX_true_range  ORN_close  ORN_dod_gain  \
# CASH_close                                NaN        NaN           NaN
# SEC_close                                 NaN        NaN           NaN
# SEC_dod_gain                              NaN        NaN           NaN
# SEC_std_1m                                NaN        NaN           NaN
# SEC_std_2m                                NaN        NaN           NaN
# SEC_std_3m                                NaN        NaN           NaN
# SEC_relative_volatility_index             NaN        NaN           NaN
# SEC_ATR                                   NaN        NaN           NaN
# SEC_BWI                                   NaN        NaN           NaN
# SEC_sigma                                 NaN        NaN           NaN
# SEC_standard_deviation                    NaN        NaN           NaN
# SEC_true_range                            NaN        NaN           NaN
# SBX_close                                 NaN        NaN           NaN
# SBX_dod_gain                              NaN        NaN           NaN
# SBX_std_1m                                NaN        NaN           NaN
# SBX_std_2m                                NaN        NaN           NaN
# SBX_std_3m                                NaN        NaN           NaN
# SBX_relative_volatility_index             NaN        NaN           NaN
# SBX_ATR                                   NaN        NaN           NaN
# SBX_BWI                                   NaN        NaN           NaN
# SBX_sigma                                 NaN        NaN           NaN
# SBX_standard_deviation                    NaN        NaN           NaN
# SBX_true_range                            1.0        NaN           NaN
# ORN_close                                 NaN        1.0           NaN
# ORN_dod_gain                              NaN        NaN           1.0
# ORN_std_1m                                NaN        NaN           NaN
# ORN_std_2m                                NaN        NaN           NaN
# ORN_std_3m                                NaN        NaN           NaN
# ORN_relative_volatility_index             NaN        NaN           NaN
# ORN_ATR                                   NaN        NaN           NaN
# ORN_BWI                                   NaN        NaN           NaN
# ORN_sigma                                 NaN        NaN           NaN
# ORN_standard_deviation                    NaN        NaN           NaN
# ORN_true_range                            NaN        NaN           NaN
# EMT_close                                 NaN        NaN           NaN
# EMT_dod_gain                              NaN        NaN           NaN
# EMT_std_1m                                NaN        NaN           NaN
# EMT_std_2m                                NaN        NaN           NaN
# EMT_std_3m                                NaN        NaN           NaN
# EMT_relative_volatility_index             NaN        NaN           NaN
# EMT_ATR                                   NaN        NaN           NaN
# EMT_BWI                                   NaN        NaN           NaN
# EMT_sigma                                 NaN        NaN           NaN
# EMT_standard_deviation                    NaN        NaN           NaN
# EMT_true_range                            NaN        NaN           NaN
# STD_avg_p1m                               NaN        NaN           NaN
#
#                                ORN_std_1m  ORN_std_2m  ORN_std_3m  \
# CASH_close                            NaN         NaN         NaN
# SEC_close                             NaN         NaN         NaN
# SEC_dod_gain                          NaN         NaN         NaN
# SEC_std_1m                            NaN         NaN         NaN
# SEC_std_2m                            NaN         NaN         NaN
# SEC_std_3m                            NaN         NaN         NaN
# SEC_relative_volatility_index         NaN         NaN         NaN
# SEC_ATR                               NaN         NaN         NaN
# SEC_BWI                               NaN         NaN         NaN
# SEC_sigma                             NaN         NaN         NaN
# SEC_standard_deviation                NaN         NaN         NaN
# SEC_true_range                        NaN         NaN         NaN
# SBX_close                             NaN         NaN         NaN
# SBX_dod_gain                          NaN         NaN         NaN
# SBX_std_1m                            NaN         NaN         NaN
# SBX_std_2m                            NaN         NaN         NaN
# SBX_std_3m                            NaN         NaN         NaN
# SBX_relative_volatility_index         NaN         NaN         NaN
# SBX_ATR                               NaN         NaN         NaN
# SBX_BWI                               NaN         NaN         NaN
# SBX_sigma                             NaN         NaN         NaN
# SBX_standard_deviation                NaN         NaN         NaN
# SBX_true_range                        NaN         NaN         NaN
# ORN_close                             NaN         NaN         NaN
# ORN_dod_gain                          NaN         NaN         NaN
# ORN_std_1m                            1.0         NaN         NaN
# ORN_std_2m                            NaN         1.0         NaN
# ORN_std_3m                            NaN         NaN         1.0
# ORN_relative_volatility_index         NaN         NaN         NaN
# ORN_ATR                               NaN         NaN         NaN
# ORN_BWI                               NaN         NaN         NaN
# ORN_sigma                             NaN         NaN         NaN
# ORN_standard_deviation                NaN         NaN         NaN
# ORN_true_range                        NaN         NaN         NaN
# EMT_close                             NaN         NaN         NaN
# EMT_dod_gain                          NaN         NaN         NaN
# EMT_std_1m                            NaN         NaN         NaN
# EMT_std_2m                            NaN         NaN         NaN
# EMT_std_3m                            NaN         NaN         NaN
# EMT_relative_volatility_index         NaN         NaN         NaN
# EMT_ATR                               NaN         NaN         NaN
# EMT_BWI                               NaN         NaN         NaN
# EMT_sigma                             NaN         NaN         NaN
# EMT_standard_deviation                NaN         NaN         NaN
# EMT_true_range                        NaN         NaN         NaN
# STD_avg_p1m                           NaN         NaN         NaN
#
#                                ORN_relative_volatility_index  ORN_ATR  \
# CASH_close                                               NaN      NaN
# SEC_close                                                NaN      NaN
# SEC_dod_gain                                             NaN      NaN
# SEC_std_1m                                               NaN      NaN
# SEC_std_2m                                               NaN      NaN
# SEC_std_3m                                               NaN      NaN
# SEC_relative_volatility_index                            NaN      NaN
# SEC_ATR                                                  NaN      NaN
# SEC_BWI                                                  NaN      NaN
# SEC_sigma                                                NaN      NaN
# SEC_standard_deviation                                   NaN      NaN
# SEC_true_range                                           NaN      NaN
# SBX_close                                                NaN      NaN
# SBX_dod_gain                                             NaN      NaN
# SBX_std_1m                                               NaN      NaN
# SBX_std_2m                                               NaN      NaN
# SBX_std_3m                                               NaN      NaN
# SBX_relative_volatility_index                            NaN      NaN
# SBX_ATR                                                  NaN      NaN
# SBX_BWI                                                  NaN      NaN
# SBX_sigma                                                NaN      NaN
# SBX_standard_deviation                                   NaN      NaN
# SBX_true_range                                           NaN      NaN
# ORN_close                                                NaN      NaN
# ORN_dod_gain                                             NaN      NaN
# ORN_std_1m                                               NaN      NaN
# ORN_std_2m                                               NaN      NaN
# ORN_std_3m                                               NaN      NaN
# ORN_relative_volatility_index                            1.0      NaN
# ORN_ATR                                                  NaN      1.0
# ORN_BWI                                                  NaN      NaN
# ORN_sigma                                                NaN      NaN
# ORN_standard_deviation                                   NaN      NaN
# ORN_true_range                                           NaN      NaN
# EMT_close                                                NaN      NaN
# EMT_dod_gain                                             NaN      NaN
# EMT_std_1m                                               NaN      NaN
# EMT_std_2m                                               NaN      NaN
# EMT_std_3m                                               NaN      NaN
# EMT_relative_volatility_index                            NaN      NaN
# EMT_ATR                                                  NaN      NaN
# EMT_BWI                                                  NaN      NaN
# EMT_sigma                                                NaN      NaN
# EMT_standard_deviation                                   NaN      NaN
# EMT_true_range                                           NaN      NaN
# STD_avg_p1m                                              NaN      NaN
#
#                                ORN_BWI  ORN_sigma  ORN_standard_deviation  \
# CASH_close                         NaN        NaN                     NaN
# SEC_close                          NaN        NaN                     NaN
# SEC_dod_gain                       NaN        NaN                     NaN
# SEC_std_1m                         NaN        NaN                     NaN
# SEC_std_2m                         NaN        NaN                     NaN
# SEC_std_3m                         NaN        NaN                     NaN
# SEC_relative_volatility_index      NaN        NaN                     NaN
# SEC_ATR                            NaN        NaN                     NaN
# SEC_BWI                            NaN        NaN                     NaN
# SEC_sigma                          NaN        NaN                     NaN
# SEC_standard_deviation             NaN        NaN                     NaN
# SEC_true_range                     NaN        NaN                     NaN
# SBX_close                          NaN        NaN                     NaN
# SBX_dod_gain                       NaN        NaN                     NaN
# SBX_std_1m                         NaN        NaN                     NaN
# SBX_std_2m                         NaN        NaN                     NaN
# SBX_std_3m                         NaN        NaN                     NaN
# SBX_relative_volatility_index      NaN        NaN                     NaN
# SBX_ATR                            NaN        NaN                     NaN
# SBX_BWI                            NaN        NaN                     NaN
# SBX_sigma                          NaN        NaN                     NaN
# SBX_standard_deviation             NaN        NaN                     NaN
# SBX_true_range                     NaN        NaN                     NaN
# ORN_close                          NaN        NaN                     NaN
# ORN_dod_gain                       NaN        NaN                     NaN
# ORN_std_1m                         NaN        NaN                     NaN
# ORN_std_2m                         NaN        NaN                     NaN
# ORN_std_3m                         NaN        NaN                     NaN
# ORN_relative_volatility_index      NaN        NaN                     NaN
# ORN_ATR                            NaN        NaN                     NaN
# ORN_BWI                            1.0        NaN                     NaN
# ORN_sigma                          NaN        1.0                     NaN
# ORN_standard_deviation             NaN        NaN                     1.0
# ORN_true_range                     NaN        NaN                     NaN
# EMT_close                          NaN        NaN                     NaN
# EMT_dod_gain                       NaN        NaN                     NaN
# EMT_std_1m                         NaN        NaN                     NaN
# EMT_std_2m                         NaN        NaN                     NaN
# EMT_std_3m                         NaN        NaN                     NaN
# EMT_relative_volatility_index      NaN        NaN                     NaN
# EMT_ATR                            NaN        NaN                     NaN
# EMT_BWI                            NaN        NaN                     NaN
# EMT_sigma                          NaN        NaN                     NaN
# EMT_standard_deviation             NaN        NaN                     NaN
# EMT_true_range                     NaN        NaN                     NaN
# STD_avg_p1m                        NaN        NaN                     NaN
#
#                                ORN_true_range  EMT_close  EMT_dod_gain  \
# CASH_close                                NaN        NaN           NaN
# SEC_close                                 NaN        NaN           NaN
# SEC_dod_gain                              NaN        NaN           NaN
# SEC_std_1m                                NaN        NaN           NaN
# SEC_std_2m                                NaN        NaN           NaN
# SEC_std_3m                                NaN        NaN           NaN
# SEC_relative_volatility_index             NaN        NaN           NaN
# SEC_ATR                                   NaN        NaN           NaN
# SEC_BWI                                   NaN        NaN           NaN
# SEC_sigma                                 NaN        NaN           NaN
# SEC_standard_deviation                    NaN        NaN           NaN
# SEC_true_range                            NaN        NaN           NaN
# SBX_close                                 NaN        NaN           NaN
# SBX_dod_gain                              NaN        NaN           NaN
# SBX_std_1m                                NaN        NaN           NaN
# SBX_std_2m                                NaN        NaN           NaN
# SBX_std_3m                                NaN        NaN           NaN
# SBX_relative_volatility_index             NaN        NaN           NaN
# SBX_ATR                                   NaN        NaN           NaN
# SBX_BWI                                   NaN        NaN           NaN
# SBX_sigma                                 NaN        NaN           NaN
# SBX_standard_deviation                    NaN        NaN           NaN
# SBX_true_range                            NaN        NaN           NaN
# ORN_close                                 NaN        NaN           NaN
# ORN_dod_gain                              NaN        NaN           NaN
# ORN_std_1m                                NaN        NaN           NaN
# ORN_std_2m                                NaN        NaN           NaN
# ORN_std_3m                                NaN        NaN           NaN
# ORN_relative_volatility_index             NaN        NaN           NaN
# ORN_ATR                                   NaN        NaN           NaN
# ORN_BWI                                   NaN        NaN           NaN
# ORN_sigma                                 NaN        NaN           NaN
# ORN_standard_deviation                    NaN        NaN           NaN
# ORN_true_range                            1.0        NaN           NaN
# EMT_close                                 NaN        1.0           NaN
# EMT_dod_gain                              NaN        NaN           1.0
# EMT_std_1m                                NaN        NaN           NaN
# EMT_std_2m                                NaN        NaN           NaN
# EMT_std_3m                                NaN        NaN           NaN
# EMT_relative_volatility_index             NaN        NaN           NaN
# EMT_ATR                                   NaN        NaN           NaN
# EMT_BWI                                   NaN        NaN           NaN
# EMT_sigma                                 NaN        NaN           NaN
# EMT_standard_deviation                    NaN        NaN           NaN
# EMT_true_range                            NaN        NaN           NaN
# STD_avg_p1m                               NaN        NaN           NaN
#
#                                EMT_std_1m  EMT_std_2m  EMT_std_3m  \
# CASH_close                            NaN         NaN         NaN
# SEC_close                             NaN         NaN         NaN
# SEC_dod_gain                          NaN         NaN         NaN
# SEC_std_1m                            NaN         NaN         NaN
# SEC_std_2m                            NaN         NaN         NaN
# SEC_std_3m                            NaN         NaN         NaN
# SEC_relative_volatility_index         NaN         NaN         NaN
# SEC_ATR                               NaN         NaN         NaN
# SEC_BWI                               NaN         NaN         NaN
# SEC_sigma                             NaN         NaN         NaN
# SEC_standard_deviation                NaN         NaN         NaN
# SEC_true_range                        NaN         NaN         NaN
# SBX_close                             NaN         NaN         NaN
# SBX_dod_gain                          NaN         NaN         NaN
# SBX_std_1m                            NaN         NaN         NaN
# SBX_std_2m                            NaN         NaN         NaN
# SBX_std_3m                            NaN         NaN         NaN
# SBX_relative_volatility_index         NaN         NaN         NaN
# SBX_ATR                               NaN         NaN         NaN
# SBX_BWI                               NaN         NaN         NaN
# SBX_sigma                             NaN         NaN         NaN
# SBX_standard_deviation                NaN         NaN         NaN
# SBX_true_range                        NaN         NaN         NaN
# ORN_close                             NaN         NaN         NaN
# ORN_dod_gain                          NaN         NaN         NaN
# ORN_std_1m                            NaN         NaN         NaN
# ORN_std_2m                            NaN         NaN         NaN
# ORN_std_3m                            NaN         NaN         NaN
# ORN_relative_volatility_index         NaN         NaN         NaN
# ORN_ATR                               NaN         NaN         NaN
# ORN_BWI                               NaN         NaN         NaN
# ORN_sigma                             NaN         NaN         NaN
# ORN_standard_deviation                NaN         NaN         NaN
# ORN_true_range                        NaN         NaN         NaN
# EMT_close                             NaN         NaN         NaN
# EMT_dod_gain                          NaN         NaN         NaN
# EMT_std_1m                            1.0         NaN         NaN
# EMT_std_2m                            NaN         1.0         NaN
# EMT_std_3m                            NaN         NaN         1.0
# EMT_relative_volatility_index         NaN         NaN         NaN
# EMT_ATR                               NaN         NaN         NaN
# EMT_BWI                               NaN         NaN         NaN
# EMT_sigma                             NaN         NaN         NaN
# EMT_standard_deviation                NaN         NaN         NaN
# EMT_true_range                        NaN         NaN         NaN
# STD_avg_p1m                           NaN         NaN         NaN
#
#                                EMT_relative_volatility_index  EMT_ATR  \
# ...
# SEC_BWI                                   NaN        NaN           NaN
# SEC_sigma                                 NaN        NaN           NaN
# SEC_standard_deviation                    NaN        NaN           NaN
# SEC_true_range                            NaN        NaN           NaN
# SBX_close                                 NaN        NaN           NaN
# SBX_dod_gain                              NaN        NaN           NaN
# SBX_std_1m                                NaN        NaN           NaN
# SBX_std_2m                                NaN        NaN           NaN
# SBX_std_3m                                NaN        NaN           NaN
# SBX_relative_volatility_index             NaN        NaN           NaN
# SBX_ATR                                   NaN        NaN           NaN
# SBX_BWI                                   NaN        NaN           NaN
# SBX_sigma                                 NaN        NaN           NaN
# SBX_standard_deviation                    NaN        NaN           NaN
# SBX_true_range                            NaN        NaN           NaN
# ORN_close                                 NaN        NaN           NaN
# ORN_dod_gain                              NaN        NaN           NaN
# ORN_std_1m                                NaN        NaN           NaN
# ORN_std_2m                                NaN        NaN           NaN
# ORN_std_3m                                NaN        NaN           NaN
# ORN_relative_volatility_index             NaN        NaN           NaN
# ORN_ATR                                   NaN        NaN           NaN
# ORN_BWI                                   NaN        NaN           NaN
# ORN_sigma                                 NaN        NaN           NaN
# ORN_standard_deviation                    NaN        NaN           NaN
# ORN_true_range                            NaN        NaN           NaN
# EMT_close                                 NaN        NaN           NaN
# EMT_dod_gain                              NaN        NaN           NaN
# EMT_std_1m                                NaN        NaN           NaN
# EMT_std_2m                                NaN        NaN           NaN
# EMT_std_3m                                NaN        NaN           NaN
# EMT_relative_volatility_index             NaN        NaN           NaN
# EMT_ATR                                   NaN        NaN           NaN
# EMT_BWI                                   NaN        NaN           NaN
# EMT_sigma                                 NaN        NaN           NaN
# EMT_standard_deviation                    NaN        NaN           NaN
# EMT_true_range                            NaN        NaN           NaN
# STD_avg_p1m                               NaN        NaN           NaN
#
#                                EMT_std_1m  EMT_std_2m  EMT_std_3m  \
# CASH_close                            NaN         NaN         NaN
# SEC_close                             NaN         NaN         NaN
# SEC_dod_gain                          NaN         NaN         NaN
# SEC_std_1m                            NaN         NaN         NaN
# SEC_std_2m                            NaN         NaN         NaN
# SEC_std_3m                            NaN         NaN         NaN
# SEC_relative_volatility_index         NaN         NaN         NaN
# SEC_ATR                               NaN         NaN         NaN
# SEC_BWI                               NaN         NaN         NaN
# SEC_sigma                             NaN         NaN         NaN
# SEC_standard_deviation                NaN         NaN         NaN
# SEC_true_range                        NaN         NaN         NaN
# SBX_close                             NaN         NaN         NaN
# SBX_dod_gain                          NaN         NaN         NaN
# SBX_std_1m                            NaN         NaN         NaN
# SBX_std_2m                            NaN         NaN         NaN
# SBX_std_3m                            NaN         NaN         NaN
# SBX_relative_volatility_index         NaN         NaN         NaN
# SBX_ATR                               NaN         NaN         NaN
# SBX_BWI                               NaN         NaN         NaN
# SBX_sigma                             NaN         NaN         NaN
# SBX_standard_deviation                NaN         NaN         NaN
# SBX_true_range                        NaN         NaN         NaN
# ORN_close                             NaN         NaN         NaN
# ORN_dod_gain                          NaN         NaN         NaN
# ORN_std_1m                            NaN         NaN         NaN
# ORN_std_2m                            NaN         NaN         NaN
# ORN_std_3m                            NaN         NaN         NaN
# ORN_relative_volatility_index         NaN         NaN         NaN
# ORN_ATR                               NaN         NaN         NaN
# ORN_BWI                               NaN         NaN         NaN
# ORN_sigma                             NaN         NaN         NaN
# ORN_standard_deviation                NaN         NaN         NaN
# ORN_true_range                        NaN         NaN         NaN
# EMT_close                             NaN         NaN         NaN
# EMT_dod_gain                          NaN         NaN         NaN
# EMT_std_1m                            NaN         NaN         NaN
# EMT_std_2m                            NaN         NaN         NaN
# EMT_std_3m                            NaN         NaN         NaN
# EMT_relative_volatility_index         NaN         NaN         NaN
# EMT_ATR                               NaN         NaN         NaN
# EMT_BWI                               NaN         NaN         NaN
# EMT_sigma                             NaN         NaN         NaN
# EMT_standard_deviation                NaN         NaN         NaN
# EMT_true_range                        NaN         NaN         NaN
# STD_avg_p1m                           NaN         NaN         NaN
#
#                                EMT_relative_volatility_index  EMT_ATR  \
# CASH_close                                               NaN      NaN
# SEC_close                                                NaN      NaN
# SEC_dod_gain                                             NaN      NaN
# SEC_std_1m                                               NaN      NaN
# SEC_std_2m                                               NaN      NaN
# SEC_std_3m                                               NaN      NaN
# SEC_relative_volatility_index                            NaN      NaN
# SEC_ATR                                                  NaN      NaN
# SEC_BWI                                                  NaN      NaN
# SEC_sigma                                                NaN      NaN
# SEC_standard_deviation                                   NaN      NaN
# SEC_true_range                                           NaN      NaN
# SBX_close                                                NaN      NaN
# SBX_dod_gain                                             NaN      NaN
# SBX_std_1m                                               NaN      NaN
# SBX_std_2m                                               NaN      NaN
# SBX_std_3m                                               NaN      NaN
# SBX_relative_volatility_index                            NaN      NaN
# SBX_ATR                                                  NaN      NaN
# SBX_BWI                                                  NaN      NaN
# SBX_sigma                                                NaN      NaN
# SBX_standard_deviation                                   NaN      NaN
# SBX_true_range                                           NaN      NaN
# ORN_close                                                NaN      NaN
# ORN_dod_gain                                             NaN      NaN
# ORN_std_1m                                               NaN      NaN
# ORN_std_2m                                               NaN      NaN
# ORN_std_3m                                               NaN      NaN
# ORN_relative_volatility_index                            NaN      NaN
# ORN_ATR                                                  NaN      NaN
# ORN_BWI                                                  NaN      NaN
# ORN_sigma                                                NaN      NaN
# ORN_standard_deviation                                   NaN      NaN
# ORN_true_range                                           NaN      NaN
# EMT_close                                                NaN      NaN
# EMT_dod_gain                                             NaN      NaN
# EMT_std_1m                                               NaN      NaN
# EMT_std_2m                                               NaN      NaN
# EMT_std_3m                                               NaN      NaN
# EMT_relative_volatility_index                            NaN      NaN
# EMT_ATR                                                  NaN      NaN
# EMT_BWI                                                  NaN      NaN
# EMT_sigma                                                NaN      NaN
# EMT_standard_deviation                                   NaN      NaN
# EMT_true_range                                           NaN      NaN
# STD_avg_p1m                                              NaN      NaN
#
#                                EMT_BWI  EMT_sigma  EMT_standard_deviation  \
# CASH_close                         NaN        NaN                     NaN
# SEC_close                          NaN        NaN                     NaN
# SEC_dod_gain                       NaN        NaN                     NaN
# SEC_std_1m                         NaN        NaN                     NaN
# SEC_std_2m                         NaN        NaN                     NaN
# SEC_std_3m                         NaN        NaN                     NaN
# SEC_relative_volatility_index      NaN        NaN                     NaN
# SEC_ATR                            NaN        NaN                     NaN
# SEC_BWI                            NaN        NaN                     NaN
# SEC_sigma                          NaN        NaN                     NaN
# SEC_standard_deviation             NaN        NaN                     NaN
# SEC_true_range                     NaN        NaN                     NaN
# SBX_close                          NaN        NaN                     NaN
# SBX_dod_gain                       NaN        NaN                     NaN
# SBX_std_1m                         NaN        NaN                     NaN
# SBX_std_2m                         NaN        NaN                     NaN
# SBX_std_3m                         NaN        NaN                     NaN
# SBX_relative_volatility_index      NaN        NaN                     NaN
# SBX_ATR                            NaN        NaN                     NaN
# SBX_BWI                            NaN        NaN                     NaN
# SBX_sigma                          NaN        NaN                     NaN
# SBX_standard_deviation             NaN        NaN                     NaN
# SBX_true_range                     NaN        NaN                     NaN
# ORN_close                          NaN        NaN                     NaN
# ORN_dod_gain                       NaN        NaN                     NaN
# ORN_std_1m                         NaN        NaN                     NaN
# ORN_std_2m                         NaN        NaN                     NaN
# ORN_std_3m                         NaN        NaN                     NaN
# ORN_relative_volatility_index      NaN        NaN                     NaN
# ORN_ATR                            NaN        NaN                     NaN
# ORN_BWI                            NaN        NaN                     NaN
# ORN_sigma                          NaN        NaN                     NaN
# ORN_standard_deviation             NaN        NaN                     NaN
# ORN_true_range                     NaN        NaN                     NaN
# EMT_close                          NaN        NaN                     NaN
# EMT_dod_gain                       NaN        NaN                     NaN
# EMT_std_1m                         NaN        NaN                     NaN
# EMT_std_2m                         NaN        NaN                     NaN
# EMT_std_3m                         NaN        NaN                     NaN
# EMT_relative_volatility_index      NaN        NaN                     NaN
# EMT_ATR                            NaN        NaN                     NaN
# EMT_BWI                            NaN        NaN                     NaN
# EMT_sigma                          NaN        NaN                     NaN
# EMT_standard_deviation             NaN        NaN                     NaN
# EMT_true_range                     NaN        NaN                     NaN
# STD_avg_p1m                        NaN        NaN                     NaN
#
#                                EMT_true_range  STD_avg_p1m
# CASH_close                                NaN          NaN
# SEC_close                                 NaN          NaN
# SEC_dod_gain                              NaN          NaN
# SEC_std_1m                                NaN          NaN
# SEC_std_2m                                NaN          NaN
# SEC_std_3m                                NaN          NaN
# SEC_relative_volatility_index             NaN          NaN
# SEC_ATR                                   NaN          NaN
# SEC_BWI                                   NaN          NaN
# SEC_sigma                                 NaN          NaN
# SEC_standard_deviation                    NaN          NaN
# SEC_true_range                            NaN          NaN
# SBX_close                                 NaN          NaN
# SBX_dod_gain                              NaN          NaN
# SBX_std_1m                                NaN          NaN
# SBX_std_2m                                NaN          NaN
# SBX_std_3m                                NaN          NaN
# SBX_relative_volatility_index             NaN          NaN
# SBX_ATR                                   NaN          NaN
# SBX_BWI                                   NaN          NaN
# SBX_sigma                                 NaN          NaN
# SBX_standard_deviation                    NaN          NaN
# SBX_true_range                            NaN          NaN
# ORN_close                                 NaN          NaN
# ORN_dod_gain                              NaN          NaN
# ORN_std_1m                                NaN          NaN
# ORN_std_2m                                NaN          NaN
# ORN_std_3m                                NaN          NaN
# ORN_relative_volatility_index             NaN          NaN
# ORN_ATR                                   NaN          NaN
# ORN_BWI                                   NaN          NaN
# ORN_sigma                                 NaN          NaN
# ORN_standard_deviation                    NaN          NaN
# ORN_true_range                            NaN          NaN
# EMT_close                                 NaN          NaN
# EMT_dod_gain                              NaN          NaN
# EMT_std_1m                                NaN          NaN
# EMT_std_2m                                NaN          NaN
# EMT_std_3m                                NaN          NaN
# EMT_relative_volatility_index             NaN          NaN
# EMT_ATR                                   NaN          NaN
# EMT_BWI                                   NaN          NaN
# EMT_sigma                                 NaN          NaN
# EMT_standard_deviation                    NaN          NaN
# EMT_true_range                            NaN          NaN
# STD_avg_p1m                               NaN          NaN

# %% [markdown]
# # **4. 해석 구간 설정**

# %%
# Date in data file: 2019-03-04 to 2021-08-20
# Example)
# train_duration = ['2019-07-01', '2019-12-31'] # YYYY-MM-DD format: six months
# test_duration  = ['2020-01-01', '2020-01-31'] # YYYY-MM-DD format: a month

train_duration = ['2020-07-01', '2020-12-31'] # YYYY-MM-DD format: six months
test_duration  = ['2021-01-01', '2021-01-31'] # YYYY-MM-DD format: a month

train_mask = (df['date'] >= train_duration[0]) & (df['date'] <= train_duration[1])
train_data = df.loc[train_mask]

test_mask = (df['date'] >= test_duration[0]) & (df['date'] <= test_duration[1])
test_data = df.loc[test_mask]

train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

train_data
# Out:
#           date    KOSPI   CASH_close  SEC_close  SEC_dod_gain   SEC_std_1m  \
# 0   2020-07-01  2106.70  186486.2990      52600     -0.378788  1503.487612
# 1   2020-07-02  2135.37  186499.9115      52900      0.570342  1475.262688
# 2   2020-07-03  2152.41  186513.5249      53600      1.323251  1432.436735
# 3   2020-07-06  2187.93  186554.3711      55000      2.611940  1320.454467
# 4   2020-07-07  2164.17  186567.9885      53400     -2.909091  1328.260140
# ..         ...      ...          ...        ...           ...          ...
# 120 2020-12-23  2759.82  188883.6659      73900      2.213001  2528.022943
# 121 2020-12-24  2806.86  188897.4534      77800      5.277402  2344.882726
# 122 2020-12-28  2808.60  188952.6131      78700      1.156812  2545.284856
# 123 2020-12-29  2820.51  188966.4056      78300     -0.508259  2751.926598
# 124 2020-12-30  2873.47  188980.1990      81000      3.448276  2653.205608
#
#       SEC_std_2m   SEC_std_3m  SEC_relative_volatility_index      SEC_ATR  \
# 0    2312.143022  2263.442926                      53.470173  1671.428571
# 1    2282.308521  2196.489467                      60.006356  1528.571429
# 2    2271.190779  2159.988329                      68.649657  1421.428571
# 3    2259.088986  2137.369857                      66.895690  1364.285714
# 4    2281.184842  2184.923666                      58.730454  1428.571429
# ..           ...          ...                            ...          ...
# 120  5634.701694  5638.342934                      62.210928  1392.857143
# 121  5652.833543  5725.041294                      62.172413  1571.428571
# 122  5768.962473  5906.825135                      62.345175  1592.857143
# 123  5852.477523  6099.390447                      61.411310  1614.285714
# 124  5807.084024  6259.620921                      62.845207  1742.857143
#
#        SEC_BWI  SEC_sigma  SEC_standard_deviation  SEC_true_range  SBX_close  \
# 0    10.938923  -0.311809              538.980519            1200     752000
# 1    10.261559  -0.052358              552.177508             800     786000
# 2     9.612422   0.545267              635.295207             900     771000
# 3     9.128354   1.592309              930.376268            1400     754000
# 4     8.322697   0.519452              795.989950            2500     751000
# ..         ...        ...                     ...             ...        ...
# 120  12.992748   0.957404              495.580468            1700     796000
# 121  13.201096   2.221755             1412.409289            4900     794000
# 122  14.522538   2.191192             2021.979228            2300     789000
# 123  14.252184   1.903358             2329.141473            1600     822000
# 124  14.547464   2.487811             2943.620220            4000     826000
#
#      SBX_dod_gain   SBX_std_1m   SBX_std_2m    SBX_std_3m  \
# 0       -2.967742  66437.63993  91599.82024  105346.34970
# 1        4.521277  58967.36385  90058.09481  103768.62970
# 2       -1.908397  52643.23318  89613.77900  102968.71390
# 3       -2.204929  46443.94471  88253.29940  101664.93930
# 4       -0.397878  38863.73631  87013.75304  100074.91080
# ..            ...          ...          ...           ...
# 120     -0.871731  19705.32923  51041.32769   60892.13129
# 121     -0.251256  19905.46407  45810.04672   60913.81517
# 122     -0.629723  20080.83664  39683.63889   60329.66409
# 123      4.182510  20479.01365  37116.79077   59666.86610
# 124      0.486618  19872.34259  33463.55685   59597.71526
#
#      SBX_relative_volatility_index      SBX_ATR    SBX_BWI  SBX_sigma  \
# 0                        44.071502  38642.85714  31.888415  -0.245899
# 1                        40.256662  34642.85714  28.014836   0.241247
# 2                        30.573788  30285.71429  24.490928  -0.163638
# 3                        17.705856  29357.14286  20.286604  -0.748770
# 4                        19.751004  28928.57143  16.439945  -1.148515
# ..                             ...          ...        ...        ...
# 120                      33.107976  24500.00000   8.471813  -0.735979
# 121                      29.593491  23357.14286   8.594408  -0.816699
# 122                      21.571295  20642.85714   8.718582  -1.020557
# 123                      27.256531  19642.85714   8.548192   0.518308
# 124                      34.245952  18928.57143   8.390389   0.644764
#
#      SBX_standard_deviation  SBX_true_range  ORN_close  ORN_dod_gain  \
# 0              19679.684960           32000     136500      1.865672
# 1              19297.927350           43000     138000      1.098901
# 2              20238.824080           32000     140000      1.449275
# 3              22990.432790           26000     146500      4.642857
# 4              24649.746450           21000     145500     -0.682594
# ..                      ...             ...        ...           ...
# 120             8879.189152           15000     124500      2.049180
# 121             9115.371633           14000     125000      0.401606
# 122             9132.360045           17000     123000     -1.600000
# 123            10507.140430           38000     122500     -0.406504
# 124            12265.398490           17000     124000      1.224490
#
#       ORN_std_1m   ORN_std_2m   ORN_std_3m  ORN_relative_volatility_index  \
# 0    3207.315856  4632.541442  7830.833702                      61.411692
# 1    3193.352470  4358.728346  7590.225896                      60.281333
# 2    3124.399942  4225.077396  7504.455364                      67.737230
# 3    3205.074102  4155.799829  7548.980080                      68.009308
# 4    3838.619544  4416.553955  7832.463676                      57.217608
# ..           ...          ...          ...                            ...
# 120  4032.601518  5060.461331  6254.426006                      37.841960
# 121  3938.591119  5074.431129  6087.278402                      43.117373
# 122  3830.469945  5079.996581  6055.075097                      41.137056
# 123  3689.512163  5052.049136  6013.768579                      39.724752
# 124  3503.212811  4695.771257  5856.636246                      41.421322
#
#          ORN_ATR    ORN_BWI  ORN_sigma  ORN_standard_deviation  \
# 0    5535.714286   8.140489   0.767219             1674.066904
# 1    5214.285714   7.964641   1.128217             1662.077014
# 2    4750.000000   7.895640   1.575627             1886.796226
# 3    5107.142857   9.431581   2.787460             3316.624790
# 4    5071.428571  10.948172   2.141142             3994.996871
# ..           ...        ...        ...                     ...
# 120  4000.000000  11.467994   0.317372             3036.856928
# 121  3964.285714  11.062391   0.378544             2619.160171
# 122  4071.428571  10.664150  -0.203279             2854.820485
# 123  4107.142857  10.265497  -0.413906             2412.985702
# 124  4107.142857   9.972805  -0.036627             2357.965225
#
#      ORN_true_range  EMT_close  EMT_dod_gain   EMT_std_1m   EMT_std_2m  \
# 0              4000     105500      0.000000  4229.657197  3424.810620
# 1              5500     107500      1.895735  4308.349452  3547.543997
# 2              4000     107500      0.000000  4217.448873  3483.324771
# 3              9500     107500      0.000000  4021.504694  3493.471433
# 4              8500     105500     -1.860465  3835.606210  3529.050004
# ..              ...        ...           ...          ...          ...
# 120            3500     149500     -0.664452  2298.233017  5027.674749
# 121            2500     151000      1.003344  2522.399651  4991.515705
# 122            4000     149500     -0.993377  2620.114501  4942.410763
# 123            2500     150500      0.668896  2802.231254  4719.653997
# 124            3000     151500      0.664452  2895.146801  4364.524937
#
#       EMT_std_3m  EMT_relative_volatility_index      EMT_ATR    EMT_BWI  \
# 0    3771.436090                      48.721262  3500.000000  15.083005
# 1    3658.034271                      56.897789  3321.428571  14.765262
# 2    3646.039477                      63.358263  3142.857143  14.341366
# 3    3606.296563                      58.428138  2964.285714  13.706652
# 4    3662.421296                      48.083336  2892.857143  12.832179
# ..           ...                            ...          ...        ...
# 120  5696.904113                      25.606518  3285.714286   6.088947
# 121  5525.927746                      33.941241  3142.857143   6.462729
# 122  5384.815463                      34.791372  2928.571429   6.804401
# 123  5177.577606                      38.628799  2964.285714   6.924400
# 124  4986.975781                      35.946541  2714.285714   6.735021
#
#      EMT_sigma  EMT_standard_deviation  EMT_true_range  STD_avg_p1m  \
# 0    -1.502896             3261.901286            1500     0.005367
# 1    -0.942513             3012.059096            2000     0.004193
# 2    -0.857888             2524.381112            2500     0.003092
# 3    -0.775627             1881.488772            2500     0.003047
# 4    -1.232856             1738.533865            3000     0.002813
# ..         ...                     ...             ...          ...
# 120  -1.883127             2030.394050            3000     0.007292
# 121  -1.183154             2034.698995            1500     0.007036
# 122  -1.552334             1613.226580            2500     0.006907
# 123  -1.096663             1483.239697            3000     0.006129
# 124  -0.672061             1229.837388            2000     0.005256
#
#      STD_yearly_f1m
# 0          0.126479
# 1          0.128883
# 2          0.127181
# 3          0.130004
# 4          0.127990
# ..              ...
# 120        0.415446
# 121        0.387179
# 122        0.343928
# 123        0.298288
# 124        0.289127
#
# [125 rows x 49 columns]

# %%
test_data
# Out:
#          date    KOSPI   CASH_close  SEC_close  SEC_dod_gain   SEC_std_1m  \
# 0  2021-01-04  2944.45  189049.1814      83000      2.469136  2849.894735
# 1  2021-01-05  2990.57  189062.9809      83900      1.084337  3290.178567
# 2  2021-01-06  2968.21  189076.7815      82200     -2.026222  3669.669604
# 3  2021-01-07  3031.68  189090.5830      82900      0.851582  3852.804174
# 4  2021-01-08  3152.18  189104.3855      88800      7.117008  4082.168541
# 5  2021-01-11  3148.45  189145.7991      91000      2.477477  4757.759452
# 6  2021-01-12  3125.95  189159.6057      90600     -0.439560  5559.532354
# 7  2021-01-13  3148.29  189173.4132      89700     -0.993377  6057.381860
# 8  2021-01-14  3149.93  189187.2218      89700      0.000000  6348.732157
# 9  2021-01-15  3085.90  189201.0314      88000     -1.895206  6547.539614
# 10 2021-01-18  3013.93  189242.4662      85000     -3.409091  6548.623901
# 11 2021-01-19  3092.66  189256.2798      87000      2.352941  6364.312610
# 12 2021-01-20  3114.55  189270.0944      87200      0.229885  6145.559372
# 13 2021-01-21  3160.84  189283.9101      88100      1.032110  5819.793811
# 14 2021-01-22  3140.63  189297.7267      86800     -1.475596  5412.806573
# 15 2021-01-25  3208.99  189339.1827      89400      2.995392  4731.342304
# 16 2021-01-26  3140.31  189353.0033      86700     -3.020134  4133.820872
# 17 2021-01-27  3122.56  189366.8250      85600     -1.268743  3746.731909
# 18 2021-01-28  3069.05  189380.6477      83700     -2.219626  3366.225631
# 19 2021-01-29  2976.21  189394.4714      82000     -2.031063  2902.804678
#
#      SEC_std_2m    SEC_std_3m  SEC_relative_volatility_index      SEC_ATR  \
# 0   5875.820851   6494.264312                      77.549599  1942.857143
# 1   6055.363255   6786.256802                      79.418548  2042.857143
# 2   6207.902124   7084.309722                      63.754592  2121.428571
# 3   6291.907685   7301.684616                      68.865007  2207.142857
# 4   6352.407067   7514.947570                      72.837921  2635.714286
# 5   6680.083070   7938.606472                      77.934719  3121.428571
# 6   7055.974049   8415.431303                      70.192175  3328.571429
# 7   7358.754453   8822.800347                      63.026864  3378.571429
# 8   7523.040951   9138.578664                      63.783137  3392.857143
# 9   7707.487649   9409.953446                      58.517591  3542.857143
# 10  7862.856302   9603.404339                      53.195176  3471.428571
# 11  7861.980139   9706.909964                      54.158360  3621.428571
# 12  7863.995621   9843.389623                      59.208324  3685.714286
# 13  7827.667947   9950.314352                      58.134917  3550.000000
# 14  7785.407115  10061.444130                      52.294912  3457.142857
# 15  7764.290044  10123.027150                      49.477617  3550.000000
# 16  7801.774535  10217.357220                      52.713511  3585.714286
# 17  7684.101343  10206.568440                      45.828479  3592.857143
# 18  7562.000717  10131.420760                      37.597911  3257.142857
# 19  7388.946195   9961.496959                      27.227159  2900.000000
#
#       SEC_BWI  SEC_sigma  SEC_standard_deviation  SEC_true_range  SBX_close  \
# 0   16.619109   2.557612             3624.375808            4200     829000
# 1   18.330264   2.344898             4075.892540            2300     832000
# 2   19.647512   1.653341             3996.110609            2400     817000
# 3   20.988713   1.609439             3752.066097            2000     819000
# 4   23.624038   2.441275             3892.364320            7100     837000
# 5   28.584783   2.331131             4124.851512            8000     846000
# 6   30.604080   1.927400             4366.050847            3600     818000
# 7   31.984669   1.568817             4266.661458            2100     830000
# 8   32.670842   1.399762             3782.274448            1300     816000
# 9   32.780081   1.031514             3365.055720            3800     804000
# 10  31.787871   0.502018             3176.727876            3900     788000
# 11  30.367215   0.733863             2987.122361            4400     796000
# 12  28.782090   0.687310             2425.469027            2500     795000
# 13  26.543947   0.765776             1738.648901            2100     796000
# 14  23.515308   0.448076             1807.456777            2900     794000
# 15  20.235776   0.954323             1623.730273            3600     790000
# 16  18.020279   0.213519             1447.204201            2900     802000
# 17  16.374178  -0.191609             1420.035211            2100     849000
# 18  14.107503  -0.969752             1560.929210            2400     838000
# 19  12.789560  -1.621869             2043.648698            3000     793000
#
#     SBX_dod_gain   SBX_std_1m   SBX_std_2m   SBX_std_3m  \
# 0       0.363196  19619.56931  30431.83155  59613.65807
# 1       0.361882  19134.00115  26871.67380  59499.94523
# 2      -1.802885  19311.33087  25349.17369  59828.57802
# 3       0.244798  19216.85458  25293.35324  59965.12020
# 4       2.197802  12536.34716  25148.71887  60009.38294
# 5       1.075269  13203.31398  24852.13859  60354.52458
# 6      -3.309693  14890.51712  24285.40884  60862.28899
# 7       1.466993  14878.17193  23267.14217  60602.94557
# 8      -1.686747  15208.87899  21847.72350  60394.73308
# 9      -1.470588  15190.45753  20226.02796  59559.49106
# 10     -1.990050  15010.32978  18457.53362  58503.89036
# 11      1.015228  16093.08858  17870.64366  57180.55817
# 12     -0.125628  16450.75986  18048.71457  55966.19032
# 13      0.125786  16780.94157  18229.48432  53658.87055
# 14     -0.251256  17085.88599  18286.17771  50159.91626
# 15     -0.503778  17448.78219  18451.98925  45911.76703
# 16      1.518987  17773.29457  18691.84020  41369.23493
# 17      5.860349  17453.07996  18703.00774  36235.84990
# 18     -1.295642  18325.11937  19491.11666  34636.98952
# 19     -5.369928  18939.11297  19770.03423  31686.25589
#
#     SBX_relative_volatility_index      SBX_ATR   SBX_BWI  SBX_sigma  \
# 0                       42.543551  19500.00000  7.950720   0.716003
# 1                       39.731145  19714.28571  7.814924   0.794870
# 2                       41.414624  20500.00000  7.850646   0.039028
# 3                       50.928818  19714.28571  5.954515   0.462655
# 4                       49.603261  19928.57143  5.354490   1.768495
# 5                       60.059144  23500.00000  6.615414   2.091935
# 6                       62.684237  26928.57143  6.768044   0.215080
# 7                       62.534246  26857.14286  6.771257   0.966541
# 8                       62.286374  26428.57143  6.771062   0.032915
# 9                       61.333655  26785.71429  6.658669  -0.779463
# 10                      59.094344  27571.42857  6.954769  -1.662204
# 11                      65.498478  28642.85714  7.250672  -1.115450
# 12                      57.734292  27214.28571  7.468508  -1.132237
# 13                      59.102367  26642.85714  7.709269  -0.974489
# 14                      51.395614  25285.71429  7.947060  -1.043053
# 15                      44.513814  25000.00000  8.180511  -1.232186
# 16                      51.115522  26142.85714  7.948562  -0.590154
# 17                      51.614716  29142.85714  7.987151   1.839006
# 18                      43.056049  29714.28571  8.208103   1.156337
# 19                      34.511162  29214.28571  8.181316  -1.103638
#
#     SBX_standard_deviation  SBX_true_range  ORN_close  ORN_dod_gain  \
# 0             13991.425950           34000     123000     -0.806452
# 1             15473.848910           16000     124000      0.813008
# 2             15195.064990           21000     124500      0.403226
# 3             14980.320420            8000     123500     -0.803213
# 4             16201.543140           25000     127500      3.238866
# 5             16926.015480           59000     122500     -3.921569
# 6             14430.869690           56000     120500     -1.632653
# 7              8754.427451           30000     122000      1.244813
# 8              9305.912099           20000     123500      1.229508
# 9             11600.000000           20000     121500     -1.619433
# 10            15855.913720           25000     118500     -2.469136
# 11            16931.922510           32000     120500      1.687764
# 12            18184.883830           18000     120000     -0.414938
# 13            18958.902920            9000     120500      0.416667
# 14            17776.670100           15000     121500      0.829876
# 15            13266.876050           12000     126000      3.703704
# 16            12251.122400           37000     123000     -2.380952
# 17            17099.707600           50000     123500      0.406504
# 18            19828.262660           33000     123000     -0.404858
# 19            20166.556470           52000     120000     -2.439024
#
#      ORN_std_1m   ORN_std_2m   ORN_std_3m  ORN_relative_volatility_index  \
# 0   3412.751822  4459.247688  5751.622465                      40.302140
# 1   3218.209906  4280.922082  5562.826768                      39.998469
# 2   3153.965758  4267.560913  5348.798738                      36.485576
# 3   3053.174577  4286.338160  5196.850596                      39.342624
# 4   2917.511782  4247.020161  5090.553297                      45.803223
# 5   2707.743526  4329.732026  5080.578869                      37.193112
# 6   2680.485031  4260.410841  4990.733149                      39.950070
# 7   2757.263136  4160.270721  4919.753797                      48.611001
# 8   2832.401808  4045.436468  4844.782364                      57.633273
# 9   2337.065468  3740.345494  4806.103349                      48.760301
# 10  2320.964239  3391.252701  4712.622925                      39.263354
# 11  2541.653005  3170.966220  4610.318749                      49.293198
# 12  2275.412051  3187.012610  4542.566452                      49.383232
# 13  2120.731006  3210.074860  4524.545616                      49.362121
# 14  2019.282051  3217.479033  4515.032076                      56.891286
# 15  2030.240134  3211.973806  4507.347163                      57.247258
# 16  2123.676058  3196.378453  4514.198687                      50.637174
# 17  2059.126028  3137.015864  4467.521421                      56.222264
# 18  2066.851470  3074.090068  4430.826393                      49.875727
# 19  2068.211788  3005.596604  4124.751098                      48.666993
#
#         ORN_ATR   ORN_BWI  ORN_sigma  ORN_standard_deviation  ORN_true_range  \
# 0   4142.857143  9.487411  -0.411720             2357.965225            3500
# 1   3964.285714  9.057984  -0.142678             1764.227876            3000
# 2   3535.714286  8.664330  -0.040941             1260.952021            3000
# 3   3250.000000  8.287205  -0.437016              916.515139            3000
# 4   3428.571429  7.551549   0.858649             1342.572158            6500
# 5   3535.714286  7.017820  -1.007280             1422.146265            6000
# 6   3678.571429  7.065894  -1.686455             1702.938637            4500
# 7   3785.714286  7.286557  -1.041519             1757.839583            3500
# 8   3678.571429  6.651173  -0.438584             1732.050808            3000
# 9   3678.571429  6.225809  -1.174081             1820.027472            3500
# 10  3785.714286  6.557539  -2.085257             2315.167381            4000
# 11  3750.000000  6.253136  -1.252520             2371.181140            3500
# 12  3821.428571  5.673356  -1.391030             2366.431913            3500
# 13  3750.000000  5.279802  -1.064735             2347.338919            2000
# 14  3785.714286  5.400234  -0.554122             1337.908816            4000
# 15  4000.000000  5.640814   1.553909             1967.866865            6000
# 16  4142.857143  5.668249   0.194257             1989.974874            5000
# 17  4142.857143  5.739528   0.423349             2062.159063            3000
# 18  3928.571429  5.732528   0.169228             2027.313493            3500
# 19  3785.714286  5.906081  -1.155262             2098.213526            4000
#
#     EMT_close  EMT_dod_gain    EMT_std_1m    EMT_std_2m    EMT_std_3m  \
# 0      151500      0.000000   2752.725922   4238.502311   4778.090956
# 1      158000      4.290429   2451.912519   4146.126250   4611.193047
# 2      155000     -1.898734   2397.394419   4125.990228   4523.817943
# 3      168500      8.709677   2343.074903   4014.844555   4433.630728
# 4      179000      6.231454   4124.318125   4316.866469   4790.813569
# 5      173500     -3.072626   6869.270340   5576.305357   5766.764817
# 6      183000      5.475504   7963.785218   6129.186280   6256.606291
# 7      179500     -1.912568   9903.787154   7326.822773   7231.255133
# 8      178000     -0.835655  11020.747480   8020.385983   7873.760423
# 9      174500     -1.966292  11755.716690   8573.959996   8384.568824
# 10     170000     -2.578797  12108.984270   8944.820601   8717.088834
# 11     172000      1.176471  12138.780830   9132.900693   8894.012976
# 12     172000      0.000000  12116.595030   9367.155651   9108.051256
# 13     175500      2.034884  12077.328970   9587.723908   9314.137521
# 14     174000     -0.854701  12072.567040   9898.503363   9553.819319
# 15     183500      5.459770  11780.704560  10111.263830   9739.029551
# 16     174500     -4.904632  11759.039080  10716.841140  10194.665330
# 17     171000     -2.005731  11213.022560  10853.220050  10321.361470
# 18     169500     -0.877193  10318.066680  10894.606230  10249.507560
# 19     164000     -3.244838   9329.255061  10901.156690  10090.360360
#
#     EMT_relative_volatility_index       EMT_ATR    EMT_BWI  EMT_sigma  \
# 0                       39.650905   2535.714286   6.092096  -0.601571
# 1                       39.895246   2785.714286   5.643216   2.106454
# 2                       39.419119   2928.571429   5.543383   0.896258
# 3                       51.572550   3750.000000   8.411476   3.588472
# 4                       67.252932   4892.857143  15.486790   3.490181
# 5                       54.153384   5642.857143  18.949299   2.213144
# 6                       63.022233   6750.000000  23.547763   2.594967
# 7                       52.608281   7571.428571  27.337282   1.912302
# 8                       45.588104   8107.142857  29.151400   1.563069
# 9                       40.848364   8428.571429  30.051452   1.143779
# 10                      35.545666   8714.285714  30.180415   0.700235
# 11                      41.149187   8964.285714  30.080731   0.781985
# 12                      40.227996   9392.857143  29.871906   0.705868
# 13                      41.850789   9714.285714  29.619100   0.900803
# 14                      40.304714  10071.428570  28.834682   0.696053
# 15                      41.504712  10178.571430  28.061826   1.360655
# 16                      40.994792  10464.285710  26.520239   0.519485
# 17                      36.293766  10035.714290  24.439045   0.121147
# 18                      28.757373   9285.714286  22.091855  -0.128628
# 19                      30.489566   9178.571429  19.684102  -0.872662
#
#     EMT_standard_deviation  EMT_true_range  STD_avg_p1m  STD_yearly_f1m
# 0              1090.871211            1500     0.004359        0.263442
# 1              2347.871376            8000     0.002965        0.259993
# 2              2524.381112            6000     0.002883        0.229811
# 3              5583.233830           14000     0.002895        0.226179
# 4              9321.480569           17500     0.004397        0.214041
# 5             10276.672610           13000     0.004763        0.201869
# 6             12159.358540           18000     0.006548        0.188992
# 7             12403.628500           14000     0.011469        0.173013
# 8             11923.191690            9500     0.013312        0.160548
# 9             10724.854310            7500     0.013757        0.199067
# 10             8785.783972            5500     0.014719        0.220917
# 11             7477.298978            6000     0.015571        0.226864
# 12             4438.468204            9000     0.015332        0.234847
# 13             3874.274126            6500     0.015010        0.235194
# 14             3736.308338            6500     0.014914        0.223964
# 15             4422.668877            9500     0.014576        0.231945
# 16             3808.214805           10000     0.014535        0.236645
# 17             3734.969879            8000     0.013066        0.244173
# 18             3808.214805            7000     0.012261        0.252762
# 19             4758.150901           11500     0.011075        0.229441

# %% [markdown]
# # **5. 위험 및 수익률 분석**

# %%
tickers = ['KOSPI', 'CASH_close', 'SEC_close', 'SBX_close', 'ORN_close', 'EMT_close']
color_code = ['0.8', '0.3', '#1428A0', '#1670BD', '#ED1D2B', '#FCB416']

plt.grid()
plt.title('Stock price charts')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Profit / loss') # 수익률
# alpha는 투명도 지정(1은 지정안함)
for idx, ticker in enumerate(tickers):
    train_data[ticker + str('_N')] = train_data[ticker] / train_data[ticker][0]
    plt.plot(train_data['date'], train_data[tickers[idx] + str('_N')],
             label=ticker, c=color_code[idx], alpha=1, linewidth=2.5)
plt.legend()

# %%
# train기간동안의 변동성과 기대수익률 계산 
volatility = []
expected_returns = []

for ticker in tickers:
    # dod_value: log(1일간 수익률) 계산상 비율은 곱해야하는데, 덧셈으로 편하게 취하기 위해서.
    dod_value = np.log(train_data[ticker + str('_N')] / train_data[ticker + str('_N')].shift(1))
    dod_value = dod_value.dropna()
    
    if ticker == 'CASH_close':
        volatility.append(0)
    else:
        volatility.append(np.sqrt(dod_value.var()*252)) #날짜기간의존성 없애려면 1년변동성으로 환산
    expected_returns.append(dod_value.mean()*252)

print(volatility)
print(expected_returns)
# Out:
# [0.1731691082843734, 0, 0.2666883899980539, 0.3689249537139051, 0.36587601414730203, 0.3495653919446356]
# [0.6308080594020916, 0.026997470877991814, 0.8773929419520241, 0.19074459106392488, -0.19518426091156701, 0.7354227205838079]

# %%
# 시각화
plt.grid()
plt.title('Expected return vs. risk (yearly)')
plt.xlabel('Expected risk')
plt.ylabel('Expected return')

for idx, ticker in enumerate(tickers):
    plt.scatter(volatility[idx], expected_returns[idx],
                label=ticker, c=color_code[idx], s=150)   
plt.legend()

# %% [markdown]
# # **6. 최적 포트폴리오 맵 (Markowitz Bullets) 생성 (GA or RS)**

# %%
# 최적의포트폴리오
# (GA를 이용하여, 리스크가 가장 적으면서 리턴이 큰 포트폴리오 찾기 )
# 여기서 RS에 의한 최적해 찾기 
# 두자산을 섞으면 상관계수에 따라서 기대리스크가 위아래로 움직일수있다.(작이질수있다)
def collective_asset_port(collective_assets, trials=100000):    
    assets = len(collective_assets) # 5 
    dod_values = train_data[collective_assets] # 5개자산의 1기준 가격흐름df (n, 5)
    assets_returns = np.log(dod_values / dod_values.shift(1)) # 5개자산의 log수익률  (n, 5)
    
    weights = []
    volatilities = []
    returns = []
    
    for i in tqdm.tqdm(range(trials)):
        # weights계산
        # 자산개수만큼 합이 1이 되도록 실수를 만들어라 
        allocated_weights = np.random.dirichlet(np.ones(assets),size=1) # array (5, )
        allocated_weights = allocated_weights[0] # array (5, )
        print("allocated_weights.shape:", allocated_weights.shape)
        weights.append(allocated_weights)
        # 포트폴리오의 변동성: wT Cov(R) w = (1,5) (5,5) (5,1) = (1,1)
        print("assets_returns.cov().shape:", assets_returns.cov().shape)
        volatilities.append(np.sqrt(np.dot(allocated_weights.T, np.dot(assets_returns.cov() * 252, allocated_weights))))
        # 포트폴리오의 수익률 
        returns.append(np.sum(assets_returns.mean() * allocated_weights) * 252)
        print("assets_returns.mean().shape:",assets_returns.mean().shape) 
        print("np.sum(assets_returns.mean() * allocated_weights) * 252).shape:",np.sum(assets_returns.mean() * allocated_weights).shape)
    
    print("weights.shape:", len(weights)) # list = ( trial 개수, asset개수)
    print("weights", weights) 
    print("returns.shape:",len(returns)) # list = (trial 개수 , 1)
    print(returns)
    print("volatilities.shape:",len(volatilities)) # list = ( trial 개수, 1)
    print(volatilities)
    df = pd.DataFrame(weights, columns=collective_assets)
    df['volatility'] = volatilities
    df['return'] = returns    
    
    plt.figure(figsize=(10, 5))
    plt.grid()    
    plt.scatter(df['volatility'], df['return'], c=(df['return']/df['volatility']), alpha=0.8)
    plt.xlabel('Expected risk')
    plt.ylabel('Expected return')
    plt.colorbar(label='Sharpe ratio (=gain/risk)')

    for idx, ticker in enumerate(tickers):
        plt.scatter(volatility[idx], expected_returns[idx],
                    label=ticker, c=color_code[idx], s=150) 
    plt.legend(loc='upper left') 
    
    return df

# %%
collect_tickers = ['CASH_close_N', 'SEC_close_N', 'SBX_close_N', 'ORN_close_N', 'EMT_close_N']

df_collect = collective_asset_port(collect_tickers, 100 ) # 200000
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 563.68it/s]
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# allocated_weights.shape: (5,)
# assets_returns.cov().shape: (5, 5)
# assets_returns.mean().shape: (5,)
# np.sum(assets_returns.mean() * allocated_weights) * 252).shape: ()
# weights.shape: 100
# weights [array([0.1338991 , 0.12542855, 0.42929568, 0.00228086, 0.30909581]), array([0.23119757, 0.36444597, 0.17982781, 0.0480231 , 0.17650555]), array([0.24282856, 0.24386711, 0.12368166, 0.18765937, 0.2019633 ]), array([0.52159275, 0.25873253, 0.00084947, 0.17262441, 0.04620084]), array([0.06558362, 0.16103137, 0.02454966, 0.58833249, 0.16050286]), array([0.06817264, 0.18079172, 0.0855656 , 0.19115595, 0.47431409]), array([0.04404539, 0.64393252, 0.08713884, 0.05993752, 0.16494574]), array([0.0841829 , 0.29622519, 0.08258716, 0.44783603, 0.08916872]), array([0.42570401, 0.23630963, 0.24009304, 0.09538159, 0.00251173]), array([0.48813256, 0.09793222, 0.25291012, 0.08021676, 0.08080835]), array([0.01590193, 0.11924808, 0.39688342, 0.10519161, 0.36277496]), array([0.34050766, 0.10507836, 0.08897781, 0.46264768, 0.0027885 ]), array([0.05584378, 0.37873262, 0.10221102, 0.31615257, 0.14706   ]), array([0.25469675, 0.35936893, 0.19574949, 0.00519119, 0.18499365]), array([0.38405337, 0.31071546, 0.22604814, 0.03836018, 0.04082285]), array([0.3660267 , 0.27122555, 0.17216761, 0.16742079, 0.02315936]), array([0.03862405, 0.42469519, 0.10491956, 0.13029295, 0.30146825]), array([0.07779256, 0.13163215, 0.15262261, 0.02188945, 0.61606322]), array([0.437251  , 0.26896668, 0.02832841, 0.12602633, 0.13942758]), array([0.53173312, 0.29976237, 0.11417437, 0.04088163, 0.01344851]), array([0.04387376, 0.0981038 , 0.59891179, 0.22049481, 0.03861585]), array([0.06111798, 0.03330142, 0.43577622, 0.32747327, 0.14233111]), array([0.23455818, 0.07254604, 0.36292409, 0.07417186, 0.25579983]), array([0.32201896, 0.06828516, 0.24461329, 0.13434486, 0.23073773]), array([0.17091806, 0.40986728, 0.05933354, 0.24607629, 0.11380484]), array([0.27961792, 0.16487994, 0.21494772, 0.20520605, 0.13534836]), array([0.25438885, 0.46372495, 0.00798244, 0.1870735 , 0.08683026]), array([0.07297407, 0.44782768, 0.24320989, 0.00829493, 0.22769343]), array([0.06964812, 0.24495297, 0.05606305, 0.00296211, 0.62637375]), array([0.00248014, 0.42890722, 0.04442088, 0.01950986, 0.5046819 ]), array([0.13197971, 0.00097001, 0.39707883, 0.2462941 , 0.22367734]), array([0.44163179, 0.11538124, 0.11054646, 0.02256669, 0.30987383]), array([0.03415876, 0.01562317, 0.54640518, 0.28787816, 0.11593473]), array([0.02342619, 0.05882712, 0.45913962, 0.34674099, 0.11186609]), array([0.27792439, 0.0350132 , 0.16863094, 0.01754052, 0.50089096]), array([0.08384608, 0.1641166 , 0.33985325, 0.38477483, 0.02740925]), array([0.0053882 , 0.74577821, 0.02712621, 0.1913743 , 0.03033308]), array([0.04365937, 0.04915369, 0.10560786, 0.77743252, 0.02414656]), array([0.0146809 , 0.27017479, 0.15100479, 0.2690622 , 0.29507731]), array([0.28259224, 0.40961045, 0.02161001, 0.09518051, 0.19100678]), array([0.38682987, 0.27355414, 0.04635768, 0.13434539, 0.15891292]), array([0.03638297, 0.06930482, 0.3238961 , 0.42008219, 0.15033391]), array([0.65847176, 0.05111497, 0.00924292, 0.16125279, 0.11991756]), array([0.04360086, 0.06152271, 0.0986617 , 0.71606054, 0.08015419]), array([0.05614775, 0.28755685, 0.11454693, 0.04655429, 0.49519417]), array([0.13531179, 0.0112438 , 0.18532109, 0.27679999, 0.39132333]), array([0.17537018, 0.22627011, 0.17888191, 0.04682315, 0.37265465]), array([0.12221531, 0.18272326, 0.18270264, 0.51002438, 0.00233441]), array([0.00305201, 0.13978068, 0.35991325, 0.17754998, 0.31970408]), array([0.06405999, 0.00501113, 0.1152    , 0.2608949 , 0.55483398]), array([0.01350176, 0.04165763, 0.11719541, 0.81170873, 0.01593647]), array([0.3229488 , 0.12693054, 0.20621872, 0.15279469, 0.19110726]), array([0.39729947, 0.20604863, 0.06377662, 0.25154268, 0.0813326 ]), array([0.60196649, 0.09079195, 0.02953512, 0.05622957, 0.22147685]), array([0.03244824, 0.46180515, 0.217748  , 0.24148577, 0.04651284]), array([0.10477421, 0.31398254, 0.11736165, 0.25798654, 0.20589506]), array([0.16453593, 0.42135315, 0.07905004, 0.19436022, 0.14070065]), array([0.08696344, 0.32384359, 0.13631776, 0.34286667, 0.1 ...
# returns.shape: 100
# [0.4224217888255605, 0.4807380917611588, 0.35601489390455543, 0.24153738613095935, 0.15094530346355062, 0.4882977683579063, 0.6923982081722648, 0.25609782734933995, 0.24785598233926234, 0.191115867306478, 0.4270213031247225, 0.030109069326720257, 0.39974442885912026, 0.4945573788012862, 0.34864022806561146, 0.26504723296480437, 0.589955620041872, 0.5954996699494779, 0.3311374871082344, 0.30105387102204945, 0.18686110124055383, 0.15474632330547816, 0.3128534925895552, 0.2587330474484021, 0.4112110047695625, 0.25269886107890077, 0.44260260315194394, 0.6071138143899036, 0.6875653842583972, 0.7522066833552611, 0.19657950591640622, 0.3577273547271175, 0.14792544238805183, 0.1544158254795878, 0.43533198730476885, 0.1561389389653874, 0.6446145673967724, -0.06953473638110196, 0.4307390082169229, 0.49303357825519906, 0.3499464431080843, 0.1521367838439733, 0.12110411454542537, -0.00684064250997987, 0.6307557854722581, 0.28262837043749434, 0.5023026637551788, 0.10063718786148337, 0.3918391669078555, 0.3852149057651598, -0.0874437073288534, 0.2701433625795392, 0.21439340399236084, 0.25344944002522496, 0.4346672297208962, 0.4017657935918022, 0.45475110179485734, 0.32646835190290774, 0.30969374670065863, 0.21296088966226004, 0.15639249958282034, 0.2875211793100443, 0.8154703539522036, 0.3383379630265359, 0.3454580870678435, 0.29461104661471904, 0.23774352020908116, 0.6006252829809156, 0.31317200855939387, 0.08075576505433901, 0.11181885018994457, 0.4061179211039051, 0.5951010061268385, 0.630215480672372, 0.576562346884841, 0.3985757616737884, 0.3670982039271843, 0.33882884064452323, 0.1596472335812415, 0.25409624489616023, 0.3524923806925898, 0.23641014078594608, 0.16881143531443896, 0.10679710600142965, 0.4472032219543578, 0.4527477865588146, 0.21900392454455123, 0.4250854485727023, 0.47568437775192535, 0.43943174223997905, 0.3317342619076461, 0.17831084992282872, 0.21479691164475204, 0.577511828811573, 0.38942527311994546, 0.35089153973544707, 0.00719832199683622, 0.126620608836916, 0.30695951878890265, 0.36051232189136645]
# volatilities.shape: 100
# [0.20057000193177396, 0.15408708622931908, 0.15037397821063272, 0.10463862571150778, 0.24356677185759423, 0.20972141985538556, 0.2040596860686868, 0.20984922043150903, 0.1317377025305673, 0.11732938417782257, 0.21494688086843208, 0.1861683447340094, 0.19434551053934493, 0.15312170031699243, 0.13546949619215654, 0.1350551552485371, 0.19264903458467325, 0.23275866130464168, 0.11417299711822389, 0.10289100665375187, 0.25887245005518533, 0.23055034108340772, 0.17398363353603954, 0.14619506006890354, 0.17091067146822905, 0.1500412916488059, 0.15945761998746072, 0.1902946961748819, 0.24056451863872863, 0.22945248657366069, 0.20632679774517657, 0.1274693658421958, 0.2521828761064882, 0.24196274227271444, 0.18763213528776723, 0.22256581925048147, 0.2250816222202151, 0.298916066504658, 0.19935663786323835, 0.14955770211366778, 0.12302711131489807, 0.22972395372513357, 0.08174237521793952, 0.28063439765212855, 0.21175294254729513, 0.20072676993032526, 0.17447710879975264, 0.22600284443405355, 0.21131260635466115, 0.2350263156236972, 0.31190919641279363, 0.13948081395838927, 0.13038814386817946, 0.09231539096117618, 0.2023718789365998, 0.1797006001129424, 0.168170713795582, 0.1928053112910891, 0.1424398553954348, 0.21698389288224998, 0.21301665639400177, 0.214489893021185, 0.2498813488953753, 0.2000209001262782, 0.16949843033541617, 0.13996412406384948, 0.23909022972030874, 0.27542279834102223, 0.1735665833658024, 0.2526328127654033, 0.23700708394366812, 0.20515659746858006, 0.18311580118635926, 0.266310369082353, 0.19034252567528104, 0.20090751354594352, 0.19578421259432507, 0.1566117507637874, 0.22185577747312213, 0.17924402704627446, 0.16514346571757574, 0.19693940212605948, 0.08096508452601128, 0.16297027119305108, 0.1254920383149685, 0.20136820472651126, 0.18172286236126606, 0.16992642733530192, 0.13019312730862923, 0.20005357457696177, 0.11679872728658465, 0.15493436158593593, 0.08504942300267271, 0.21445525302994492, 0.21996173388064572, 0.12390654274783806, 0.20339810135859376, 0.20582846776135655, 0.11586801557022522, 0.232279890161441]

# %% [markdown]
# # **7. 최적 자산배분 전략**

# %%
def portfolio_table(data_table=df_collect):
    data_table['volatility_round'] = data_table['volatility'].round(2)
    data_table['neg_return'] = -data_table['return']

    data_table = data_table.sort_values(by=['volatility_round', 'neg_return'])
    data_table = data_table.drop_duplicates(subset=['volatility_round'])
    data_table = data_table.reset_index(drop=True)

    plt.figure(figsize=(10, 5))
    plt.grid()
    plt.xlim(data_table['volatility_round'].min(), data_table['volatility_round'].max())
    plt.ylim(0, 1)
    plt.title('Optimal allocation of collected assets')
    plt.xlabel('Risk')
    plt.ylabel('Allocation ratio')
    plt.stackplot(data_table['volatility_round'],
                  data_table[collect_tickers[0]],
                  data_table[collect_tickers[1]],
                  data_table[collect_tickers[2]],
                  data_table[collect_tickers[3]],
                  data_table[collect_tickers[4]],
                  colors=color_code[1:],
                  labels=collect_tickers)

    plt.legend(loc='lower left') 

    return data_table

# %%
df_collect_port = portfolio_table(df_collect)

# %% [markdown]
# # **8. 탐색적 데이터 분석**

# %%
y_train = train_data['STD_yearly_f1m']
x_train = train_data.drop(['date', 'STD_yearly_f1m'], axis=1)
x_train = x_train.drop([x for x in x_train.columns if '_N' in x], axis=1)

y_test = test_data['STD_yearly_f1m']
x_test = test_data.drop(['date', 'STD_yearly_f1m'], axis=1)

# %%
x_train

# %%
x_test

# %%
plt.figure(figsize=(25, 250))

for i in range(1, len(x_train.describe().columns)):
    plt.subplot(40, 4, i)
    title = str(x_train.describe().columns[i]) + ' vs. volatility'
    plt.title(title)
    plt.xlabel(x_train.describe().columns[i])
    plt.ylabel('volatility')
    plt.grid()
    plt.scatter(x_train[x_train.describe().columns[i]], y_train)

# %% [markdown]
# # **9. 데이터 스케일링**

# %%
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # **10. GA에 의한 최적모델 자동 생성**

# %%
# Elastic Net
en_model = ElasticNet(max_iter=100000000, random_state=42)

en_param = {'l1_ratio': Continuous(0, 1),
            'alpha': Continuous(1e-6, 1e0, distribution='log-uniform'),
            'tol': Continuous(1e-6, 1e0, distribution='log-uniform')}

en_clf = GASearchCV(estimator=en_model, param_grid=en_param, n_jobs=-1, verbose=True, scoring='r2', generations=300,
                    cv=TimeSeriesSplit())

en_clf.fit(x_train_scaled, y_train, callbacks=ProgressBar())

y_train_pred_en = en_clf.predict(x_train_scaled)
y_test_pred_en = en_clf.predict(x_test_scaled)

print('Best_estimator:', en_clf.best_estimator_)
print('Best_params:', en_clf.best_params_)
print('Best_score:', en_clf.best_score_)
train_score = r2_score(y_train_pred_en, y_train)
print('Train score:', train_score)
test_score = r2_score(y_test_pred_en, y_test)
print('Test  score:', test_score)

plt.figure(figsize=(5, 5))
plt.title('Prediction vs ground truth scatter plot')
plt.xlabel('Prediction')
plt.ylabel('Ground truth')
plt.grid()
plt.scatter(y_test_pred_en, y_test)
plt.grid()
plt.show()

plot_fitness_evolution(en_clf)
plt.show()

plot_search_space(en_clf, features=['l1_ratio', 'alpha', 'tol'])

# %%
# Random Forest
rf_model = RandomForestRegressor(n_jobs=-1, random_state=42)

rf_param = {'n_estimators': Integer(2, 80),
            'max_depth': Integer(2, 40),
            'min_samples_split': Integer(2, 10)}

rf_clf = GASearchCV(estimator=rf_model, param_grid=rf_param, n_jobs=-1, verbose=True, scoring='r2', generations=12,
                    cv=TimeSeriesSplit())

rf_clf.fit(x_train_scaled, y_train, callbacks=ProgressBar())

y_train_pred_rf = rf_clf.predict(x_train_scaled)
y_test_pred_rf = rf_clf.predict(x_test_scaled)

print('Best_estimator:', rf_clf.best_estimator_)
print('Best_params:', rf_clf.best_params_)
print('Best_score:', rf_clf.best_score_)
train_score = r2_score(y_train_pred_rf, y_train)
print('Train score:', train_score)
test_score = r2_score(y_test_pred_rf, y_test)
print('Test  score:', test_score)

plt.figure(figsize=(5, 5))
plt.title('Prediction vs ground truth scatter plot')
plt.xlabel('Prediction')
plt.ylabel('Ground truth')
plt.grid()
plt.scatter(y_test_pred_rf, y_test)
plt.grid()
plt.show()

plot_fitness_evolution(rf_clf)
plt.show()

plot_search_space(rf_clf, features=['n_estimators', 'max_depth', 'min_samples_split'])

# %%
# XGBoost
xgb_model = XGBRegressor(n_jobs=-1, random_state=42)

xgb_param = {'n_estimators': Integer(2, 600),
             'max_depth': Integer(1, 40),
             'reg_alpha': Continuous(1e-6, 1e2, distribution='log-uniform'),
             'reg_lambda': Continuous(1e-6, 1e2, distribution='log-uniform')}

xgb_clf = GASearchCV(estimator=xgb_model, param_grid=xgb_param, n_jobs=-1, verbose=True, scoring='r2', generations=60,
                     cv=TimeSeriesSplit())

xgb_clf.fit(x_train_scaled, y_train, callbacks=ProgressBar())

y_train_pred_xgb = xgb_clf.predict(x_train_scaled)
y_test_pred_xgb = xgb_clf.predict(x_test_scaled)

print('Best_estimator:', xgb_clf.best_estimator_)
print('Best_params:', xgb_clf.best_params_)
print('Best_score:', xgb_clf.best_score_)
train_score = r2_score(y_train_pred_xgb, y_train)
print('Train score:', train_score)
test_score = r2_score(y_test_pred_xgb, y_test)
print('Test  score:', test_score)

plt.figure(figsize=(5, 5))
plt.title('Prediction vs ground truth scatter plot')
plt.xlabel('Prediction')
plt.ylabel('Ground truth')
plt.grid()
plt.scatter(y_test_pred_xgb, y_test)
plt.grid()
plt.show()

plot_fitness_evolution(xgb_clf)
plt.show()

plot_search_space(xgb_clf, features=['n_estimators', 'max_depth', 'reg_alpha', 'reg_lambda'])

# %%
# Support Vector Machine
svr_model = SVR()

svr_param = {'C': Continuous(1e-3, 1e8, distribution='log-uniform'),
             'gamma': Continuous(1e-6, 1e5, distribution='log-uniform')}

svr_clf = GASearchCV(estimator=svr_model, param_grid=svr_param, n_jobs=-1, verbose=True, scoring='r2', generations=300,
                     cv=TimeSeriesSplit())

svr_clf.fit(x_train_scaled, y_train, callbacks=ProgressBar())

y_train_pred_svr = svr_clf.predict(x_train_scaled)
y_test_pred_svr = svr_clf.predict(x_test_scaled)

print('Best_estimator:', svr_clf.best_estimator_)
print('Best_params:', svr_clf.best_params_)
print('Best_score:', svr_clf.best_score_)
train_score = r2_score(y_train_pred_svr, y_train)
print('Train score:', train_score)
test_score = r2_score(y_test_pred_svr, y_test)
print('Test  score:', test_score)

plt.figure(figsize=(5, 5))
plt.title('Prediction vs ground truth scatter plot')
plt.xlabel('Prediction')
plt.ylabel('Ground truth')
plt.grid()
plt.scatter(y_test_pred_svr, y_test)
plt.grid()
plt.show()

plot_fitness_evolution(svr_clf)
plt.show()

plot_search_space(svr_clf, features=['C', 'gamma'])

# %%
# Voting ensemble
y_train_array = np.stack((y_train_pred_en, y_train_pred_rf, y_train_pred_xgb, y_train_pred_svr))
y_train_pred_ensemble = np.average(y_train_array, axis=0)

y_test_array = np.stack((y_test_pred_en, y_test_pred_rf, y_test_pred_xgb, y_test_pred_svr))
y_test_pred_ensemble = np.average(y_test_array, axis=0)

train_score = r2_score(y_train_pred_ensemble, y_train)
print('Train score:', train_score)
test_score = r2_score(y_test_pred_ensemble, y_test)
print('Test  score:', test_score)

train_score = mean_absolute_error(y_train_pred_ensemble, y_train)
print('Train error (MAE):', train_score)
test_score = mean_absolute_error(y_test_pred_ensemble, y_test)
print('Test  error (MAE):', test_score)

print('Train std:', y_train.std())
print('Test  std:', y_test.std())

plt.figure(figsize=(5, 5))
plt.title('Prediction vs ground truth scatter plot')
plt.xlabel('Prediction')
plt.ylabel('Ground truth')
plt.grid()
plt.scatter(y_test_pred_ensemble, y_test)

# %%
y_test_pred_ensemble[0]

# %%
df_collect_port

# %% [markdown]
# # **11. 최적 배분 자산 예측**

# %%
pred_target = y_test_pred_ensemble[0].round(2)

if (pred_target <= df_collect_port['volatility_round'].max()) & (pred_target >= df_collect_port['volatility_round'].min()):
    final_allocation = df_collect_port[df_collect_port['volatility_round'] == y_test_pred_ensemble[0].round(2)]
elif pred_target > df_collect_port['volatility_round'].max():
    final_allocation = df_collect_port[df_collect_port['volatility_round'] == df_collect_port['volatility_round'].max()]
else:
    final_allocation = df_collect_port[df_collect_port['volatility_round'] == df_collect_port['volatility_round'].min()]

final_allocation

# %%
pie_labels = [] 
pie_ratio = []
for i in list(final_allocation)[0:5]:    
    pie_labels.append(i[:-2])
    pie_ratio.append(float(final_allocation[i].values))
plt.figure(figsize=(5, 5))
plt.pie(pie_ratio, labels=pie_labels, shadow=True, startangle=90, colors=color_code[1:], autopct='%1.1f%%')

# %%
test_data.head(5)

# %%
pie_ratio

# %% [markdown]
# # **12. 동적 자산 배분 성과 평가**

# %%
asset = 10000000 # Total amount of the investment asset

stock_prices = test_data.loc[0][pie_labels]
stock_shares = []

for i in range(len(pie_ratio)):
    stock_shares.append(asset * pie_ratio[i] / stock_prices[i])

stock_shares

# %%
investment = np.empty(len(test_data))

for i in range(len(pie_labels)):
    investment += test_data[pie_labels[i]] * stock_shares[i]

test_data['investment_asset'] = investment

# %%
test_data

# %%
test_data['KOSPI_ref'] = test_data['KOSPI'] / test_data.loc[0]['KOSPI']
test_data['ROI'] = test_data['investment_asset'] / test_data.loc[0]['investment_asset']

# %%
test_data

# %%
plt.figure(figsize=(10, 5))
plt.title('Daily investment performance')
plt.xlabel('Day')
plt.ylabel('Return(%)')

x = np.arange(len(test_data))
plt.grid()
plt.bar(x - 0.2, (test_data['ROI']/test_data['ROI'].shift(1) - 1)*100, width=0.4, label='Investment assets')
plt.bar(x + 0.2, (test_data['KOSPI_ref']/test_data['KOSPI_ref'].shift(1) - 1)*100, width=0.4, label='KOSPI reference')
plt.legend()

# %%
plt.figure(figsize=(10, 5))
plt.title('Daily investment performance')
plt.xlabel('Date')
plt.ylabel('Accumulated profit (%)')

plt.grid()
plt.plot(test_data['date'], (test_data['ROI'] - 1)*100, '-o', label='Investment assets', c='r')
plt.plot(test_data['date'], (test_data['KOSPI_ref'] - 1)*100, '-o', label='KOSPI reference', c='b')
plt.legend()

# %%
# Appendix

# %%
# Training 기간 6개월 + Test 기간 한 달 sliding window로 예측한 결과 및 퍼포먼스 비교

xlabel = ['Dec-19', 'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20',
          'May-20', 'Jun-20', 'Jul-20', 'Aug-20', 'Sep-20',
          'Oct-20', 'Nov-20', 'Dec-20', 'Jan-21', 'Feb-21',
          'Mar-21', 'Apr-21', 'May-21', 'Jun-21', 'Jul-21']

kospi_perf = [1, 0.9741, 0.91351098, 0.800418321, 0.92488337,
              0.990365112, 1.011063743, 1.079512758, 1.115568484, 1.105193698,
              1.061538547, 1.196353942, 1.30498288, 1.319076695, 1.300213898,
              1.311395738, 1.337099094, 1.369858022, 1.401638728, 1.367999399]

investment_perf = [1, 1.1058, 1.0676499, 1.100960577, 1.409669923,
                   1.495800755, 1.689656533, 1.66566341, 1.741950794, 1.575594493,
                   1.562832178, 1.668010783, 1.793611995, 1.919344196, 1.911858754,
                   1.875915809, 1.867474188, 1.852534395, 1.855683703, 1.905230458]

plt.figure(figsize=(10, 5))
plt.title('Monthly investment performance')
plt.xlabel('Month-Year')
plt.ylabel('Geometrically accumulated profit')
plt.xticks(rotation=90)

plt.grid()
plt.plot(xlabel, investment_perf, '-o', label='Investment assets', c='r')
plt.plot(xlabel, kospi_perf, '-o', label='KOSPI reference', c='b')
plt.legend()
